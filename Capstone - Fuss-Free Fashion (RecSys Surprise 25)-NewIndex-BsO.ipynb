# %% [markdown]
# #### <font color=blue>BaselineOnly</font>
#
# [UCSD](https://cseweb.ucsd.edu/~jmcauley/datasets.html#clothing_fit) dataset on clothing fit
#
# **Item-based CF**:
# - <font color=red>items usually don't change much</font> so this approach can be computed offline
# - uses patterns of users who browsed the same item as active user
# - <font color=blue>"Users who liked this item also liked ..."</font>
#
# **User-based CF**:
# - use k-nearest neighbors to find <font color=red>clusters of similar users based on common item ratings</font>
# - then make predictions using the <font color=red>average rating of top k-nearest neighbors</font>
#
# - <font color=blue>"Users who are similar to you also liked ..."</font>

# %%
## importing modules 

import pandas as pd
import random
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
% config InlineBackend.figure_format = 'retina'
plt.style.use('fivethirtyeight')
import itertools

# surprise modules
from surprise import Dataset
from surprise import Reader
from surprise.model_selection import cross_validate
from surprise.model_selection import train_test_split
from surprise.model_selection import KFold
from surprise.model_selection import GridSearchCV
from surprise import NormalPredictor
from surprise import BaselineOnly
from surprise import SlopeOne
from surprise import CoClustering
from surprise import KNNBasic
from surprise import KNNWithMeans
from surprise import KNNWithZScore
from surprise import KNNBaseline
from surprise import SVD
from surprise import SVDpp
from surprise import NMF
from surprise import accuracy
from surprise.accuracy import rmse

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns',None)

# %%
## read csv file

df = pd.read_csv('renttherunway_reduced25_new.csv')

print(df.shape)
df.head()
# Out:
# (1874, 26)
#     age          body type bust size category  fit height  item_id  rating  \
# 0  32.0          hourglass       32c    dress  fit  5' 3"   143094     5.0
# 1  38.0  straight & narrow       34c    dress  fit  5' 8"   143094     2.0
# 2  37.0           athletic       36c    dress  fit  5' 4"   143094     5.0
# 3  47.0           athletic       34b    dress  fit  5' 5"   145417     5.0
# 4  36.0               pear       34c    dress  fit  5' 7"   145417     4.0
#
#   rented for review_date                                     review_summary  \
# 0      party  2015-04-07                  glamorous like a sexy disco ball!
# 1   vacation  2012-11-25  looked like a showstopper but i was itching al...
# 2      party  2014-04-15          perfect dress for my bachelorette party!
# 3      other  2014-01-15                     great for work-to-dinner party
# 4      party  2016-01-20                                      charity event
#
#                                          review_text  size  user_id  weight  \
# 0  few friends and i wore this dress and went to ...     8   610914  140lbs
# 1  the dress fit great, but the sequins did not l...     8    53519  135lbs
# 2  fit perfectly without being too tight. materia...     8   470639  138lbs
# 3  form fitting and flattering.  this dress was c...     8   276186  120lbs
# 4  this dress is a great color and is a nubby mat...     8   748397  125lbs
#
#    band_size cup_size  feet  inches  height_inch  weight_lbs  year  month  \
# 0       32.0        c     5       3           63       140.0  2015      4
# 1       34.0        c     5       8           68       135.0  2012     11
# 2       36.0        c     5       4           64       138.0  2014      4
# 3       34.0        b     5       5           65       120.0  2014      1
# 4       34.0        c     5       7           67       125.0  2016      1
#
#    day  item_id_size  item_id_new
# 0    7      14309408        751.0
# 1   25      14309408        751.0
# 2   15      14309408        751.0
# 3   15      14541708        804.0
# 4   20      14541708        804.0

# %%
## Ratings distribution

df['rating'].value_counts()
# Out:
# 5.0    1220
# 4.0     495
# 3.0     123
# 2.0      28
# 1.0       8
# Name: rating, dtype: int64

# %%
df['user_id'].nunique()
# Out:
# 755

# %%
df['item_id_new'].nunique()
# Out:
# 797

# %% [markdown]
# <div class='alert alert-danger'>
# #### Using the Surprise module
# - load dataset from pandas dataframe using `Dataset.load_from_df`
#
# #### Algorithms to compare:
# - `NormalPredictor`: predicts random rating based on training set which is assumed to be normally distributed
# - `BaselineOnly`: predicts the baseline estimate for a given user and given item
# - `Slope One`: factors in items that a user liked separately from items that a user disliked (by computing the average difference between ratings of one item and another for users who rated both)
# - `Co-clustering`: simultaneous clustering of users and items
#
# **Neighborhood collaborative filtering (CF)**:
# - `KNNBasic`: basic nearest neighbors CF algorithm
# - `KNNWithMeans`: takes into account the mean ratings of each user
# - `KNNWithZScore`: takes into account the z-score normalization of each user
# - `KNNBaseline`: takes into account a baseline rating
#
# **Matrix factorization CF**:
# - `SVD`: singular value decomposition is equivalent to [Probabilistic Matrix Factorization, PMF](http://papers.nips.cc/paper/3208-probabilistic-matrix-factorization.pdf) if baselines are not used
# - `SVDpp or SVD++`: takes into account implicit ratings
# - `NMF`: non-negative matrix factorization
#
# #### Model selection:
# - manually split data into training set and test set (80-20)
# - use `cross_validate` to select model with lowest RSME score
# - use `GridSearchCV` to tune hyperparameters for ratings prediction

# %%
## create reader and load specific columns from dataframe into surprise

reader = Reader(rating_scale=(1,5))

data = Dataset.load_from_df(df[['user_id','item_id_new','rating']], reader)

data1 = Dataset.load_from_df(df[['user_id','item_id_new','rating']], reader)

# %% [markdown]
# <div class='alert alert-warning'>
# #### [manually split data](https://surprise.readthedocs.io/en/stable/FAQ.html#how-to-save-some-data-for-unbiased-accuracy-estimation) into training set and test set

# %%
raw_ratings = data.raw_ratings

random.shuffle(raw_ratings)

# set training set as 80% of the data, test set as 20%
threshold = int(0.8 * len(raw_ratings))

train_raw_ratings = raw_ratings[:threshold]
test_raw_ratings = raw_ratings[threshold:]

data.raw_ratings = train_raw_ratings

# %% [markdown]
# <div class='alert alert-warning'>
# #### compare algorithms using cross validation and pre-defined training set (80%)
# - using metrics: `RMSE`, `MAE`

# %%
comparison = []

algos = [NormalPredictor(), BaselineOnly(), SlopeOne(), CoClustering(),\
         KNNBasic(), KNNWithMeans(), KNNWithZScore(), KNNBaseline(),\
         SVD(), SVDpp(), NMF()]

for algorithm in algos:
    score = cross_validate(algorithm, data, measures=['RMSE','MAE'],\
                             cv=5, verbose=False)
    
    result = pd.DataFrame.from_dict(score).mean(axis=0)
    result = result.append(pd.Series([str(algorithm).split(' ')[0].\
                                      split('.')[-1]],\
                                     index=['Algorithm']))
    comparison.append(result)
# Out:
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
pd.DataFrame(comparison).set_index('Algorithm').\
sort_values('test_rmse',ascending=True)
# Out:
#                  test_rmse  test_mae  fit_time  test_time
# Algorithm
# SVDpp             0.718094  0.574995  0.190531   0.004922
# BaselineOnly      0.718583  0.585430  0.004629   0.001855
# KNNBasic          0.722063  0.593298  0.007969   0.004966
# SVD               0.722208  0.581793  0.088207   0.035633
# KNNBaseline       0.722897  0.586878  0.012171   0.003039
# SlopeOne          0.817845  0.593147  0.019058   0.002861
# KNNWithMeans      0.817911  0.593796  0.014404   0.003317
# KNNWithZScore     0.830081  0.591335  0.033119   0.003436
# CoClustering      0.868189  0.639699  0.138463   0.002229
# NormalPredictor   0.933886  0.685216  0.003042   0.003674
# NMF               1.065608  0.855579  0.194102   0.002340

# %% [markdown]
# <div class='alert alert-danger'>
# #### use the 4 best algorithms to get predictions for existing testset ratings:
# - `BaselineOnly()`, `SVDpp()`, `SVD()`, `KNNWithZScore()`
# - create dataframe for predictions of existing testset ratings
# - note: lower RMSE/MAE is better

# %%
def get_items(user_id):
    """ returns the number of items rated by a given user
    args: 
      uid: the 'raw' id of the user
    """
    try:
        return len(trainset.ur[trainset.to_inner_uid(user_id)])
            # to_inner_uid() converts raw user id to inner id

    except ValueError: # user was not part of the trainset
        return 0
    
def get_users(item_id):
    """ returns number of users that have rated a given item
    args:
      iid: the raw id of the item
    """
    try: 
        return len(trainset.ir[trainset.to_inner_iid(item_id)])
            # to_inner_iid() converts raw item id to inner id
    except ValueError:
        return 0

# %% [markdown]
# ### predict using BaselineOnly

# %%
## use Alternating Least Squares (ALS) for BaselineOnly

trainset = data.build_full_trainset()

bsl_options = {'method':'als', 'n_epochs': 5, 'reg_u':12, 'reg_i': 5}

algo1 = BaselineOnly(bsl_options=bsl_options)
algo1.fit(trainset)

predictions1_biased = algo1.test(trainset.build_testset())
print('Biased accuracy on training set (BaselineOnly): ', end='   ')
accuracy.rmse(predictions1_biased)

###########################################################
testset = data.construct_testset(test_raw_ratings)
predictions1_unbiased = algo1.test(testset)
print('Unbiased accuracy on test set (BaselineOnly): ', end='   ')
accuracy.rmse(predictions1_unbiased)
# Out:
# Estimating biases using als...
# Biased accuracy on training set (BaselineOnly):    RMSE: 0.5878
# Unbiased accuracy on test set (BaselineOnly):    RMSE: 0.7266
# 0.72660380759287

# %%
# checking that the train-test split is indeed 80-20

print('length of the train set: ',trainset.n_ratings)
print('length of the test set: ',len(testset))
# Out:
# length of the train set:  1499
# length of the test set:  375

# %%
## top 10 best and worst predictions for the testset using BaselineOnly

df_BsO = pd.DataFrame(predictions1_unbiased, columns=['uid','iid','actual rating',\
                                                      'estimated rating','details'])
df_BsO['number of items for target user'] = df_BsO['uid'].apply(get_items)
df_BsO['number of users for target item'] = df_BsO['iid'].apply(get_users)
df_BsO['error'] = abs(df_BsO['estimated rating'] - df_BsO['actual rating'])

Best_predictions_BsO = df_BsO.sort_values(by='error')[:10]
Best_predictions_BsO
# Out:
#         uid      iid  actual rating  estimated rating  \
# 197  551741     68.0            4.0          3.965975
# 338  995412     72.0            4.0          3.934905
# 302  439590     72.0            4.0          4.106401
# 200  327294  16609.0            4.0          4.109715
# 142  290985  18707.0            5.0          4.844951
# 52   507493  11966.0            5.0          4.839009
# 27    32925  22933.0            5.0          4.829292
# 92   393306     72.0            4.0          4.177287
# 40   897249  11507.0            5.0          4.808972
# 309  890869  27119.0            5.0          4.808891
#
#                        details  number of items for target user  \
# 197  {'was_impossible': False}                                1
# 338  {'was_impossible': False}                                3
# 302  {'was_impossible': False}                                4
# 200  {'was_impossible': False}                                4
# 142  {'was_impossible': False}                                6
# 52   {'was_impossible': False}                                3
# 27   {'was_impossible': False}                                5
# 92   {'was_impossible': False}                                0
# 40   {'was_impossible': False}                                0
# 309  {'was_impossible': False}                                0
#
#      number of users for target item     error
# 197                                2  0.034025
# 338                                5  0.065095
# 302                                5  0.106401
# 200                                1  0.109715
# 142                                2  0.155049
# 52                                 4  0.160991
# 27                                 3  0.170708
# 92                                 5  0.177287
# 40                                 9  0.191028
# 309                                7  0.191109

# %%
Worst_predictions_BsO = df_BsO.sort_values(by='error')[-10:]
Worst_predictions_BsO
# Out:
#         uid      iid  actual rating  estimated rating  \
# 243  741924  27529.0            3.0          4.615715
# 110  930348    361.0            3.0          4.640789
# 325  776382   9608.0            3.0          4.646212
# 44   388317   1366.0            3.0          4.772748
# 319  778579  25372.0            2.0          4.330153
# 260   96369  16162.0            2.0          4.414175
# 352  432828  29295.0            2.0          4.549033
# 11   645325    169.0            2.0          4.585268
# 286  933801   1666.0            1.0          4.574656
# 116  497208  12287.0            1.0          4.673311
#
#                        details  number of items for target user  \
# 243  {'was_impossible': False}                                0
# 110  {'was_impossible': False}                                1
# 325  {'was_impossible': False}                                1
# 44   {'was_impossible': False}                                2
# 319  {'was_impossible': False}                                4
# 260  {'was_impossible': False}                                3
# 352  {'was_impossible': False}                                0
# 11   {'was_impossible': False}                                0
# 286  {'was_impossible': False}                                1
# 116  {'was_impossible': False}                                2
#
#      number of users for target item     error
# 243                                6  1.615715
# 110                                1  1.640789
# 325                                1  1.646212
# 44                                 3  1.772748
# 319                                3  2.330153
# 260                                2  2.414175
# 352                                0  2.549033
# 11                                 3  2.585268
# 286                                0  3.574656
# 116                                1  3.673311

# %% [markdown]
# <div class='alert alert-warning'>
# #### get top-N recommendations for each user
#
# - first train each algorithm on the whole dataset
# - then predict all the **ratings for user-item pairs that are not in** the dataset
# - retrieve top-N predictions for each user

# %%
## using get_top_n function from surprise library

from collections import defaultdict

def get_top_n(predictions, n):
    ''' 
    Return the top-N recommendation for each user from set of predictions.
        
    Args:
    predictions(list of Prediction objects): The list of predictions,
        as returned by the test method of an algorithm.
    n(int): The number of recommendation to output for each user. 
    Default is 10.

    Returns:
    A dict where keys are user (raw) ids and values are lists of
        tuples: [(raw item id, rating estimation), ...] of size n.
    '''
        
    # First map the predictions to each user.
    top_n = defaultdict(list)
    
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the 
        # k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n


def get_categ(itemID):
    ''' 
    Returns item category for a given itemID
    '''
    category = df[df['item_id_new']==itemID]['category'].values[0]
    
    return category


def get_existing(userID):
    ''' 
    Returns list of at most 10 random items that user has rented
    '''
    existing = df[df['user_id']==userID]['item_id_new']
    exdict = {}
    if len(existing) < 10:
        exist = list(df[df['user_id']==userID]['item_id_new'].\
                     sample(n=len(existing), random_state=1))
        exdict[userID] = [(a, get_categ(a)) for a in exist]
    else:
        exist = list(df[df['user_id']==userID]['item_id_new'].\
                     sample(n=10, random_state=1))
        exdict[userID] = [(a, get_categ(a)) for a in exist]
    return exdict

# %%
## train BaselineOnly algorithm on the whole dataset

trainset = data1.build_full_trainset()

bsl_options = {'method':'als', 'n_epochs': 5, 'reg_u':12, 'reg_i': 5}

algo = BaselineOnly(bsl_options=bsl_options)
algo.fit(trainset)

## predict all ratings (for user-item pairs) that are not in the train set
testset = trainset.build_anti_testset()
predictions_BsO = algo.test(testset)
accuracy.rmse(predictions_BsO)

topNPredicted_BsO = get_top_n(predictions_BsO, 10)

BsO_recc_dict = {}
BsO_exist_dict = {}

## print existing and recommended items for each user:
i=0
for uid, user_ratings in topNPredicted_BsO.items():
    exitem = get_existing(uid)
    
    print("Random 10 rented items for user {0}: {1}".\
          format(uid, list(a for a in exitem.values())[0]))
    BsO_exist_dict[uid] = list(a for a in exitem.values())[0]
    print()
    
    BsO_recc_dict[uid] = [(iid,get_categ(iid)) for (iid,_) in user_ratings]
    print('Top 10 recommended new items for user {0}: {1}'.\
          format(uid, [(iid,get_categ(iid)) for (iid,_) in user_ratings]))
    print('-------------------------------------------------------------')
    
    i+=1
print('Number of recommended item sets (BaselineOnly):', i)
# Out:
# Estimating biases using als...
# RMSE: 0.1561
# Random 10 rented items for user 610914: [(751.0, 'dress')]
#
# Top 10 recommended new items for user 610914: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 53519: [(751.0, 'dress'), (8003.0, 'dress')]
#
# Top 10 recommended new items for user 53519: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 470639: [(414.0, 'gown'), (528.0, 'dress'), (22588.0, 'dress'), (751.0, 'dress'), (878.0, 'dress')]
#
# Top 10 recommended new items for user 470639: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress'), (14597.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 276186: [(804.0, 'dress')]
#
# Top 10 recommended new items for user 276186: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 748397: [(17879.0, 'dress'), (800.0, 'sheath'), (5093.0, 'dress'), (804.0, 'dress'), (26856.0, 'jumpsuit')]
#
# Top 10 recommended new items for user 748397: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress'), (14597.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 856829: [(9499.0, 'dress'), (1276.0, 'mini'), (804.0, 'dress'), (545.0, 'sheath')]
#
# Top 10 recommended new items for user 856829: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 990544: [(804.0, 'dress')]
#
# Top 10 recommended new items for user 990544: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 214108: [(8157.0, 'dress')]
#
# Top 10 recommended new items for user 214108: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 503301: [(524.0, 'dress'), (1387.0, 'dress'), (8157.0, 'dress'), (1450.0, 'dress')]
#
# Top 10 recommended new items for user 503301: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 574571: [(16499.0, 'dress'), (1005.0, 'mini'), (8157.0, 'dress'), (1602.0, 'dress')]
#
# Top 10 recommended new items for user 574571: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 407375: [(1304.0, 'gown')]
#
# Top 10 recommended new items for user 407375: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 78488: [(584.0, 'gown'), (4816.0, 'sheath'), (1304.0, 'gown'), (20188.0, 'shift')]
#
# Top 10 recommended new items for user 78488: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress'), (14597.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 871986: [(24183.0, 'romper')]
#
# Top 10 recommended new items for user 871986: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 290985: [(1204.0, 'gown'), (65.0, 'dress'), (9604.0, 'dress'), (24183.0, 'romper'), (18707.0, 'sheath'), (269.0, 'dress'), (800.0, 'sheath')]
#
# Top 10 recommended new items for user 290985: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 26196: [(3886.0, 'dress'), (212.0, 'gown'), (2159.0, 'dress'), (24183.0, 'romper'), (28976.0, 'romper'), (15587.0, 'gown'), (971.0, 'sheath')]
#
# Top 10 recommended new items for user 26196: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 166307: [(18254.0, 'dress'), (72.0, 'dress'), (16609.0, 'dress'), (24183.0, 'romper'), (19742.0, 'sheath'), (539.0, 'sheath')]
#
# Top 10 recommended new items for user 166307: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 234006: [(418.0, 'gown'), (14306.0, 'dress'), (170.0, 'dress'), (29560.0, 'jumpsuit')]
#
# Top 10 recommended new items for user 234006: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 408945: [(13488.0, 'sheath'), (137.0, 'gown'), (12669.0, 'dress'), (170.0, 'dress'), (274.0, 'dress'), (1264.0, 'gown'), (701.0, 'gown')]
#
# Top 10 recommended new items for user 408945: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 480020: [(170.0, 'dress'), (85.0, 'dress'), (7637.0, 'dress')]
#
# Top 10 recommended new items for user 480020: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 916978: [(170.0, 'dress'), (4783.0, 'dress'), (567.0, 'gown')]
#
# Top 10 recommended new items for user 916978: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 971553: [(170.0, 'dress'), (5783.0, 'dress'), (523.0, 'shift')]
#
# Top 10 recommended new items for user 971553: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 526586: [(170.0, 'dress')]
#
# Top 10 recommended new items for user 526586: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 648369: [(170.0, 'dress'), (12289.0, 'dress')]
#
# Top 10 recommended new items for user 648369: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 339506: [(170.0, 'dress'), (710.0, 'dress'), (2560.0, 'maxi')]
#
# Top 10 recommended new items for user 339506: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 571227: [(170.0, 'dress')]
#
# Top 10 recommended new items for user 571227: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 968500: [(29560.0, 'jumpsuit'), (169.0, 'dress')]
#
# Top 10 recommended new items for user 968500: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 806600: [(14306.0, 'dress')]
#
# Top 10 recommended new items for user 806600: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 84770: [(14306.0, 'dress'), (21954.0, 'shift'), (10377.0, 'dress')]
#
# Top 10 recommended new items for user 84770: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 269712: [(29231.0, 'jumpsuit'), (20951.0, 'sheath'), (1592.0, 'dress'), (11122.0, 'dress'), (21781.0, 'sheath')]
#
# Top 10 recommended new items for user 269712: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 736692: [(11122.0, 'dress')]
#
# Top 10 recommended new items for user 736692: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 853733: [(11122.0, 'dress'), (11741.0, 'dress'), (15859.0, 'maxi')]
#
# Top 10 recommended new items for user 853733: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 600534: [(11740.0, 'dress'), (26856.0, 'jumpsuit'), (386.0, 'gown'), (11122.0, 'dress'), (14161.0, 'shift'), (526.0, 'dress')]
#
# Top 10 recommended new items for user 600534: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 673553: [(11122.0, 'dress'), (1087.0, 'dress')]
#
# Top 10 recommended new items for user 673553: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 477583: [(6732.0, 'dress'), (1240.0, 'dress'), (7154.0, 'sheath'), (11122.0, 'dress'), (10885.0, 'sheath')]
#
# Top 10 recommended new items for user 477583: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 649434: [(20951.0, 'sheath'), (27119.0, 'jumpsuit')]
#
# Top 10 recommended new items for user 649434: [(11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress'), (14597.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 560601: [(19288.0, 'gown'), (1368.0, 'dress'), (21848.0, 'dress'), (19596.0, 'gown'), (20951.0, 'sheath'), (1277.0, 'mini'), (29295.0, 'romper'), (22129.0, 'gown')]
#
# Top 10 recommended new items for user 560601: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 941136: [(20951.0, 'sheath'), (203.0, 'dress')]
#
# Top 10 recommended new items for user 941136: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 852045: [(20951.0, 'sheath')]
#
# Top 10 recommended new items for user 852045: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user
0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 859301: [(24584.0, 'jumpsuit'), (1278.0, 'mini'), (22220.0, 'sheath'), (7637.0, 'dress'), (28975.0, 'romper'), (10884.0, 'sheath'), (936.0, 'dress')]
#
# Top 10 recommended new items for user 859301: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 386336: [(7637.0, 'dress'), (216.0, 'gown')]
#
# Top 10 recommended new items for user 386336: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 539191: [(7637.0, 'dress'), (10303.0, 'dress')]
#
# Top 10 recommended new items for user 539191: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 520431: [(7637.0, 'dress')]
#
# Top 10 recommended new items for user 520431: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 855337: [(1690.0, 'dress'), (20713.0, 'sheath'), (23057.0, 'dress'), (8852.0, 'dress'), (1614.0, 'maxi'), (5781.0, 'dress'), (14304.0, 'dress'), (16009.0, 'maxi'), (527.0, 'dress'), (16715.0, 'dress')]
#
# Top 10 recommended new items for user 855337: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 134521: [(1614.0, 'maxi'), (1375.0, 'dress')]
#
# Top 10 recommended new items for user 134521: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 771439: [(17879.0, 'dress'), (16009.0, 'maxi'), (2533.0, 'dress'), (1614.0, 'maxi'), (24584.0, 'jumpsuit'), (20168.0, 'gown')]
#
# Top 10 recommended new items for user 771439: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress'), (14597.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 76139: [(10375.0, 'dress'), (527.0, 'dress'), (1739.0, 'dress'), (14304.0, 'dress'), (18951.0, 'dress')]
#
# Top 10 recommended new items for user 76139: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 601243: [(1690.0, 'dress'), (9738.0, 'dress')]
#
# Top 10 recommended new items for user 601243: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 500378: [(17669.0, 'dress'), (243.0, 'gown'), (300.0, 'gown'), (1690.0, 'dress'), (10884.0, 'sheath'), (662.0, 'dress'), (7089.0, 'gown')]
#
# Top 10 recommended new items for user 500378: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 820028: [(876.0, 'dress'), (526.0, 'dress'), (1406.0, 'dress'), (1690.0, 'dress'), (581.0, 'gown')]
#
# Top 10 recommended new items for user 820028: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 411872: [(23413.0, 'shift'), (168.0, 'dress'), (16503.0, 'dress'), (1690.0, 'dress'), (1094.0, 'dress')]
# Top 10 recommended new items for user 411872: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 517738: [(5781.0, 'dress')]
#
# Top 10 recommended new items for user 517738: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 51748: [(5781.0, 'dress')]
#
# Top 10 recommended new items for user 51748: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 540884: [(8852.0, 'dress'), (4780.0, 'dress'), (16830.0, 'dress')]
#
# Top 10 recommended new items for user 540884: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 635670: [(12668.0, 'dress'), (9605.0, 'dress'), (83.0, 'dress'), (16715.0, 'dress'), (10884.0, 'sheath'), (19768.0, 'dress')]
#
# Top 10 recommended new items for user 635670: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 772324: [(23057.0, 'dress'), (8391.0, 'sheath'), (14429.0, 'sheath')]
#
# Top 10 recommended new items for user 772324: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 416568: [(23057.0, 'dress'), (17511.0, 'gown'), (546.0, 'sheath')]
#
# Top 10 recommended new items for user 416568: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 107556: [(16009.0, 'maxi')]
#
# Top 10 recommended new items for user 107556: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 611557: [(16009.0, 'maxi'), (19787.0, 'dress')]
#
# Top 10 recommended new items for user 611557: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 295662: [(527.0, 'dress'), (17444.0, 'gown')]
#
# Top 10 recommended new items for user 295662: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 991099: [(1611.0, 'maxi'), (28447.0, 'jumpsuit'), (212.0, 'gown'), (527.0, 'dress'), (41.0, 'gown')]
#
# Top 10 recommended new items for user 991099: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 316497: [(19742.0, 'sheath'), (23058.0, 'dress'), (527.0, 'dress'), (1390.0, 'dress')]
#
# Top 10 recommended new items for user 316497: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 258496: [(9607.0, 'dress'), (528.0, 'dress'), (801.0, 'sheath'), (20713.0, 'sheath'), (1711.0, 'dress')]
#
# Top 10 recommended new items for user 258496: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress'), (14597.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 942693: [(297.0, 'gown'), (22808.0, 'dress'), (811.0, 'gown'), (18779.0, 'gown'), (2252.0, 'dress')]
#
# Top 10 recommended new items for user 942693: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 297521: [(18779.0, 'gown'), (1177.0, 'dress')]
#
# Top 10 recommended new items for user 297521: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 140422: [(20901.0, 'dress')]
#
# Top 10 recommended new items for user 140422: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 106267: [(20901.0, 'dress'), (15020.0, 'sheath')]
#
# Top 10 recommended new items for user 106267: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 904958: [(9605.0, 'dress'), (1417.0, 'dress'), (20901.0, 'dress'), (14429.0, 'sheath')]
#
# Top 10 recommended new items for user 904958: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 975196: [(20901.0, 'dress'), (3798.0, 'dress')]
#
# Top 10 recommended new items for user 975196: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 26892: [(20901.0, 'dress')]
#
# Top 10 recommended new items for user 26892: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 112320: [(20901.0, 'dress'), (1451.0, 'dress')]
#
# Top 10 recommended new items for user 112320: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 276572: [(20901.0, 'dress'), (8069.0, 'dress')]
#
# Top 10 recommended new items for user 276572: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 827596: [(20901.0, 'dress'), (10303.0, 'dress')]
#
# Top 10 recommended new items for user 827596: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 995412: [(22220.0, 'sheath'), (72.0, 'dress'), (8069.0, 'dress'), (20901.0, 'dress'), (23413.0, 'shift')]
#
# ...
# Random 10 rented items for user 131947: [(28598.0, 'blazer')]
#
# Top 10 recommended new items for user 131947: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 970672: [(28598.0, 'blazer')]
#
# Top 10 recommended new items for user 970672: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 448164: [(28598.0, 'blazer')]
#
# Top 10 recommended new items for user 448164: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 175980: [(6980.0, 'dress')]
#
# Top 10 recommended new items for user 175980: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 730602: [(6980.0, 'dress')]
#
# Top 10 recommended new items for user 730602: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 348121: [(74.0, 'dress')]
#
# Top 10 recommended new items for user 348121: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 772923: [(11450.0, 'dress')]
#
# Top 10 recommended new items for user 772923: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 24677: [(1453.0, 'dress'), (1372.0, 'dress')]
#
# Top 10 recommended new items for user 24677: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 167512: [(1534.0, 'dress')]
#
# Top 10 recommended new items for user 167512: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 545454: [(6731.0, 'dress')]
#
# Top 10 recommended new items for user 545454: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 182971: [(446.0, 'dress')]
#
# Top 10 recommended new items for user 182971: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 452119: [(443.0, 'dress'), (508.0, 'dress')]
#
# Top 10 recommended new items for user 452119: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 113893: [(20189.0, 'shift')]
#
# Top 10 recommended new items for user 113893: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 53764: [(4602.0, 'gown')]
#
# Top 10 recommended new items for user 53764: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 751304: [(9329.0, 'dress'), (275.0, 'dress'), (742.0, 'gown')]
#
# Top 10 recommended new items for user 751304: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 752510: [(1374.0, 'dress'), (779.0, 'gown'), (12285.0, 'dress')]
#
# Top 10 recommended new items for user 752510: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 733593: [(16504.0, 'dress')]
#
# Top 10 recommended new items for user 733593: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 735087: [(16504.0, 'dress')]
#
# Top 10 recommended new items for user 735087: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 159233: [(20410.0, 'dress'), (9324.0, 'dress')]
#
# Top 10 recommended new items for user 159233: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 500817: [(18263.0, 'dress')]
# Top 10 recommended new items for user 500817: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 456267: [(752.0, 'dress')]
#
# Top 10 recommended new items for user 456267: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 517328: [(17278.0, 'dress')]
#
# Top 10 recommended new items for user 517328: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 261528: [(4826.0, 'dress')]
#
# Top 10 recommended new items for user 261528: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 796775: [(17786.0, 'sheath'), (294.0, 'gown'), (23412.0, 'shift')]
#
# Top 10 recommended new items for user 796775: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 616928: [(113.0, 'gown'), (634.0, 'gown'), (761.0, 'sheath'), (975.0, 'sheath')]
#
# Top 10 recommended new items for user 616928: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 840347: [(975.0, 'sheath'), (341.0, 'gown')]
#
# Top 10 recommended new items for user 840347: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 994907: [(12291.0, 'dress')]
#
# Top 10 recommended new items for user 994907: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 106273: [(1179.0, 'dress')]
#
# Top 10 recommended new items for user 106273: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 727936: [(23305.0, 'sheath')]
#
# Top 10 recommended new items for user 727936: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 401021: [(389.0, 'gown')]
#
# Top 10 recommended new items for user 401021: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 335672: [(1603.0, 'dress')]
#
# Top 10 recommended new items for user 335672: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 930348: [(361.0, 'gown'), (19457.0, 'sheath')]
#
# Top 10 recommended new items for user 930348: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 910934: [(47.0, 'gown')]
#
# Top 10 recommended new items for user 910934: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 474493: [(490.0, 'gown')]
#
# Top 10 recommended new items for user 474493: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 688256: [(1020.0, 'gown')]
#
# Top 10 recommended new items for user 688256: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 714474: [(15920.0, 'sheath'), (17974.0, 'dress'), (17141.0, 'sheath')]
#
# Top 10 recommended new items for user 714474: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 198899: [(722.0, 'gown')]
#
# Top 10 recommended new items for user 198899: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 266462: [(8538.0, 'dress')]
#
# Top 10 recommended new items for user 266462: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 293159: [(14025.0, 'dress')]
#
# Top 10 recommended new items for user 293159: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 601986: [(18073.0, 'gown')]
#
# Top 10 recommended new items for user 601986: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 230384: [(20718.0, 'dress')]
#
# Top 10 recommended new items for user 230384: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 192415: [(737.0, 'gown'), (15108.0, 'sheath')]
#
# Top 10 recommended new items for user 192415: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (4816.0, 'sheath'), (544.0, 'sheath'), (17879.0, 'dress'), (528.0, 'dress'), (10883.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Number of recommended item sets (BaselineOnly): 755

# %%
## compare results for BaselineOnly

df_exist = pd.DataFrame.from_dict(BsO_exist_dict,orient='index',\
                                  columns=['rent1','rent2','rent3',\
                                           'rent4','rent5','rent6',\
                                           'rent7','rent8','rent9',\
                                           'rent10']).reset_index()

df_rec = pd.DataFrame.from_dict(BsO_recc_dict, orient='index',\
                                columns=['rec1','rec2','rec3','rec4',\
                                         'rec5','rec6','rec7','rec8',\
                                         'rec9','rec10']).reset_index()

df_compare = pd.concat([df_exist, df_rec], axis=1).\
rename(columns={'index':'item ID'})

df_compare
# Out:
#      item ID                rent1              rent2              rent3  \
# 0     610914       (751.0, dress)               None               None
# 1      53519       (751.0, dress)    (8003.0, dress)               None
# 2     470639        (414.0, gown)     (528.0, dress)   (22588.0, dress)
# 3     276186       (804.0, dress)               None               None
# 4     748397     (17879.0, dress)    (800.0, sheath)    (5093.0, dress)
# 5     856829      (9499.0, dress)     (1276.0, mini)     (804.0, dress)
# 6     990544       (804.0, dress)               None               None
# 7     214108      (8157.0, dress)               None               None
# 8     503301       (524.0, dress)    (1387.0, dress)    (8157.0, dress)
# 9     574571     (16499.0, dress)     (1005.0, mini)    (8157.0, dress)
# 10    407375       (1304.0, gown)               None               None
# 11     78488        (584.0, gown)   (4816.0, sheath)     (1304.0, gown)
# 12    871986    (24183.0, romper)               None               None
# 13    290985       (1204.0, gown)      (65.0, dress)    (9604.0, dress)
# 14     26196      (3886.0, dress)      (212.0, gown)    (2159.0, dress)
# 15    166307     (18254.0, dress)      (72.0, dress)   (16609.0, dress)
# 16    234006        (418.0, gown)   (14306.0, dress)     (170.0, dress)
# 17    408945    (13488.0, sheath)      (137.0, gown)   (12669.0, dress)
# 18    480020       (170.0, dress)      (85.0, dress)    (7637.0, dress)
# 19    916978       (170.0, dress)    (4783.0, dress)      (567.0, gown)
# 20    971553       (170.0, dress)    (5783.0, dress)     (523.0, shift)
# 21    526586       (170.0, dress)               None               None
# 22    648369       (170.0, dress)   (12289.0, dress)               None
# 23    339506       (170.0, dress)     (710.0, dress)     (2560.0, maxi)
# 24    571227       (170.0, dress)               None               None
# 25    968500  (29560.0, jumpsuit)     (169.0, dress)               None
# 26    806600     (14306.0, dress)               None               None
# 27     84770     (14306.0, dress)   (21954.0, shift)   (10377.0, dress)
# 28    269712  (29231.0, jumpsuit)  (20951.0, sheath)    (1592.0, dress)
# 29    736692     (11122.0, dress)               None               None
# ..       ...                  ...                ...                ...
# 725   113893     (20189.0, shift)               None               None
# 726    53764       (4602.0, gown)               None               None
# 727   751304      (9329.0, dress)     (275.0, dress)      (742.0, gown)
# 728   752510      (1374.0, dress)      (779.0, gown)   (12285.0, dress)
# 729   733593     (16504.0, dress)               None               None
# 730   735087     (16504.0, dress)               None               None
# 731   159233     (20410.0, dress)    (9324.0, dress)               None
# 732   500817     (18263.0, dress)               None               None
# 733   456267       (752.0, dress)               None               None
# 734   517328     (17278.0, dress)               None               None
# 735   261528      (4826.0, dress)               None               None
# 736   796775    (17786.0, sheath)      (294.0, gown)   (23412.0, shift)
# 737   616928        (113.0, gown)      (634.0, gown)    (761.0, sheath)
# 738   840347      (975.0, sheath)      (341.0, gown)               None
# 739   994907     (12291.0, dress)               None               None
# 740   106273      (1179.0, dress)               None               None
# 741   727936    (23305.0, sheath)               None               None
# 742   401021        (389.0, gown)               None               None
# 743   335672      (1603.0, dress)               None               None
# 744   930348        (361.0, gown)  (19457.0, sheath)               None
# 745   910934         (47.0, gown)               None               None
# 746   474493        (490.0, gown)               None               None
# 747   688256       (1020.0, gown)               None               None
# 748   714474    (15920.0, sheath)   (17974.0, dress)  (17141.0, sheath)
# 749   198899        (722.0, gown)               None               None
# 750   266462      (8538.0, dress)               None               None
# 751   293159     (14025.0, dress)               None               None
# 752   601986      (18073.0, gown)               None               None
# 753   230384     (20718.0, dress)               None               None
# 754   192415        (737.0, gown)  (15108.0, sheath)               None
#
#                    rent4                rent5            rent6  \
# [rec metrics Python library (from source 2)](https://github.com/statisticianinstilettos/recmetrics)

# %% [markdown]
# <div class='alert alert-warning'>
# **Coverage**:
# - <font color=red>what % of user-item space can be recommended?</font>
# - **User coverage**: measures the percentage of users with at least one "good" recommendation (rating above a certain threshold). A higher value is better. (numUsers = trainset.n_users)
# - **Item coverage**: measures the percentage of recommended items (with a rating above a certain threshold). A higher value is better. (numItems = trainset.n_items)

# %%
## % of items in train set that model is able to recommend on a test set

def Coverage(predicted, length):
    """
    Computes the coverage for a list of recommendations
    Parameters:
    ----------
    predicted : a dictionary of lists (of item-rating pairs)
    
    length: integer
        The number of unique items in the whole training set
    
    Returns:
    ----------
    The coverage of the recommendations as a percent 
    rounded to 2 decimal places.
    """
    predicted_items = [iid for uid, user_ratings in predicted.items()\
                       for (iid, _) in user_ratings]
    unique_pred_items = len(set(predicted_items))
    coverage = round(unique_pred_items/(length*1.0)*100,2)/100
    return coverage

## for the top N recommendations, the train set is the whole dataset

print('Item coverage using BaselineOnly: {:.2%}'.\
      format(Coverage(topNPredicted_BsO,len(df))))

# print('Item coverage using SVDpp: {:.2%}'.\
#       format(Coverage(topNPredicted_SVDpp,len(df))))

# print('Item coverage using SVD: {:.2%}'.\
#       format(Coverage(topNPredicted_SVD,len(df))))

# print('Item coverage using KNNWithZScore: {:.2%}'.\
#       format(Coverage(topNPredicted_KNNZ,len(df))))
# Out:
# Item coverage using BaselineOnly: 0.64%

# %%
def UserCoverage(topNPredicted, numUsers, min_rating=4.0):
    hits = 0
    for user in topNPredicted.keys():
        hit = False
        for user_ratings in topNPredicted[user]:
            if (user_ratings[1] >= min_rating):
                hit = True
                break
        if (hit):
            hits += 1

    return hits / numUsers

print('User coverage using BaselineOnly: {:.2%}'.\
      format(UserCoverage(topNPredicted_BsO, len(df))))

# print('User coverage using SVDpp: {:.2%}'.\
#       format(UserCoverage(topNPredicted_SVDpp, len(df))))

# print('User coverage using SVD: {:.2%}'.\
#       format(UserCoverage(topNPredicted_SVD, len(df))))

# print('User coverage using KNNWithZScore: {:.2%}'.\
#       format(UserCoverage(topNPredicted_KNNZ, len(df))))
# Out:
# User coverage using BaselineOnly: 40.29%

# %% [markdown]
# <div class='alert alert-warning'>
# **Novelty**:
# - <font color=red>how surprising are the recommendations?</font>
# - measures how many unknown recommended items are to a user (serendipity vs popularity)
# - <font color=red>popular items: must have the best rating of 5</font>
# - higher novelty value = less popular items being recommended

# %%
df_cleaned = pd.read_csv('renttherunway_cleaned_new.csv')
print(df_cleaned.shape)

## popular items must have a rating of 5 using overall cleaned dataset

popular = df_cleaned[df_cleaned['rating']==5]['item_id_new'].value_counts()

## assign rank based on item count
ranking_pop = pd.DataFrame(popular).rename(columns={'item_id_new':\
                                                    'item_count'})
ranking_pop['rank'] = ranking_pop['item_count'].rank(method='dense',\
                                                     ascending=False)
ranking_pop.head()
# Out:
# (190004, 26)
#         item_count  rank
# 168.0          245   1.0
# 1389.0         223   2.0
# 66.0           205   3.0
# 169.0          200   4.0
# 546.0          195   5.0

# %%
def Novelty(topNPredicted):
    n = 0
    total = 0
    for user in topNPredicted.keys():
        for rating in topNPredicted[user]:
            itemID = rating[0]
            rank = ranking_pop.loc[itemID,'rank']
#             print('Item ID: {0} is ranked {1}'.format(itemID,rank))
#             if rank > 259:
#                 print('error')
            total += rank
            n += 1
    return round(total / n, 2)

print('Novelty score using BaselineOnly: ', Novelty(topNPredicted_BsO))

# print('Novelty score using SVDpp: ',\
#        Novelty(topNPredicted_SVDpp))

# print('Novelty score using SVD: ', Novelty(topNPredicted_SVD))

# print('Novelty score using KNNWithZScore: ', Novelty(topNPredicted_KNNZ))
# Out:
# Novelty score using BaselineOnly:  71.12

# %% [markdown]
# <div class='alert alert-warning'>
# #### compare algorithms using KFold and whole data set
# - using metrics: `Precision@k` and `Recall@k` functions from Surprise library
# <img src="./screenshots/precision_recall.png" width=300 />
#
# - an item is <font color=blue>considered relevant</font> if its <font color=red>true rating $r_{ui}$</font> is <font color=red>greater than a given threshold</font>.
# - an item is <font color=blue>considered recommended</font> if its <font color=red>estimated rating $\hat r_{ui}$ is greater than the threshold</font>, and if it is <font color=red>among the k highest estimated ratings</font>.

# %%
## use precision@k and recall@k functions from Surprise library

def precision_recall_at_k(predictions, k=10, threshold=5.0):
    '''Return precision and recall at k metrics for each user.'''

    # First map the predictions to each user.
    user_est_true = defaultdict(list)
    for uid, _, true_r, est, _ in predictions:
        user_est_true[uid].append((est, true_r))

    precisions = dict()
    recalls = dict()
    for uid, user_ratings in user_est_true.items():

        # Sort user ratings by estimated value
        user_ratings.sort(key=lambda x: x[0], reverse=True)

        # Number of relevant items
        n_rel = sum((true_r >= threshold) for (_, true_r) in user_ratings)

        # Number of recommended items in top k
        n_rec_k = sum((est >= threshold) for (est, _) in user_ratings[:k])

        # Number of relevant and recommended items in top k
        n_rel_and_rec_k = sum(((true_r>=threshold) and (est>=threshold))
                              for (est, true_r) in user_ratings[:k])
        # Precision@K: Proportion of recommended items that are relevant
        precisions[uid] = n_rel_and_rec_k / n_rec_k if n_rec_k != 0 else 1

        # Recall@K: Proportion of relevant items that are recommended
        recalls[uid] = n_rel_and_rec_k / n_rel if n_rel != 0 else 1

    return precisions, recalls

# %%
# calculate average precision and recall for BaselineOnly

kf = KFold(n_splits=5)

bsl_options = {'method':'als', 'n_epochs': 5, 'reg_u':12, 'reg_i': 5}
algo = BaselineOnly(bsl_options=bsl_options)

pmetrics = {}
rmetrics = {}
a=1

for trainset, testset in kf.split(data1):
    algo.fit(trainset)
    predictions = algo.test(testset)
    precisions, recalls = precision_recall_at_k(predictions, k=5,\
                                                threshold=5.0)

    # Precision and recall can then be averaged over all users
    pmetrics[a] = (sum(prec for prec in precisions.values())\
                    / len(precisions))
    rmetrics[a] = (sum(rec for rec in recalls.values()) / len(recalls))
    a +=1

print('average precision for BaselineOnly: ',\
      float(sum(pmetrics.values()))/len(pmetrics))

print('average recall for BaselineOnly: ',\
      float(sum(rmetrics.values()))/len(rmetrics))
# Out:
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# average precision for BaselineOnly:  1.0
# average recall for BaselineOnly:  0.28238508202640167
