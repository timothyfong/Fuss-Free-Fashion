# %% [markdown]
# #### <font color=blue>SVDpp - NewIndex</font>
#
# [UCSD](https://cseweb.ucsd.edu/~jmcauley/datasets.html#clothing_fit) dataset on clothing fit
#
# **Item-based CF**:
# - <font color=red>items usually don't change much</font> so this approach can be computed offline
# - uses patterns of users who browsed the same item as active user
# - <font color=blue>"Users who liked this item also liked ..."</font>
#
# **User-based CF**:
# - use k-nearest neighbors to find <font color=red>clusters of similar users based on common item ratings</font>
# - then make predictions using the <font color=red>average rating of top k-nearest neighbors</font>
#
# - <font color=blue>"Users who are similar to you also liked ..."</font>

# %%
## importing modules 

import pandas as pd
import random
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
% config InlineBackend.figure_format = 'retina'
plt.style.use('fivethirtyeight')
import itertools

# surprise modules
from surprise import Dataset
from surprise import Reader
from surprise.model_selection import cross_validate
from surprise.model_selection import train_test_split
from surprise.model_selection import KFold
from surprise.model_selection import GridSearchCV
from surprise import NormalPredictor
from surprise import BaselineOnly
from surprise import SlopeOne
from surprise import CoClustering
from surprise import KNNBasic
from surprise import KNNWithMeans
from surprise import KNNWithZScore
from surprise import KNNBaseline
from surprise import SVD
from surprise import SVDpp
from surprise import NMF
from surprise import accuracy
from surprise.accuracy import rmse

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns',None)

# %%
## read csv file

df = pd.read_csv('renttherunway_reduced25_new.csv')

print(df.shape)
df.head()
# Out:
# (1874, 26)
#     age          body type bust size category  fit height  item_id  rating  \
# 0  32.0          hourglass       32c    dress  fit  5' 3"   143094     5.0
# 1  38.0  straight & narrow       34c    dress  fit  5' 8"   143094     2.0
# 2  37.0           athletic       36c    dress  fit  5' 4"   143094     5.0
# 3  47.0           athletic       34b    dress  fit  5' 5"   145417     5.0
# 4  36.0               pear       34c    dress  fit  5' 7"   145417     4.0
#
#   rented for review_date                                     review_summary  \
# 0      party  2015-04-07                  glamorous like a sexy disco ball!
# 1   vacation  2012-11-25  looked like a showstopper but i was itching al...
# 2      party  2014-04-15          perfect dress for my bachelorette party!
# 3      other  2014-01-15                     great for work-to-dinner party
# 4      party  2016-01-20                                      charity event
#
#                                          review_text  size  user_id  weight  \
# 0  few friends and i wore this dress and went to ...     8   610914  140lbs
# 1  the dress fit great, but the sequins did not l...     8    53519  135lbs
# 2  fit perfectly without being too tight. materia...     8   470639  138lbs
# 3  form fitting and flattering.  this dress was c...     8   276186  120lbs
# 4  this dress is a great color and is a nubby mat...     8   748397  125lbs
#
#    band_size cup_size  feet  inches  height_inch  weight_lbs  year  month  \
# 0       32.0        c     5       3           63       140.0  2015      4
# 1       34.0        c     5       8           68       135.0  2012     11
# 2       36.0        c     5       4           64       138.0  2014      4
# 3       34.0        b     5       5           65       120.0  2014      1
# 4       34.0        c     5       7           67       125.0  2016      1
#
#    day  item_id_size  item_id_new
# 0    7      14309408        751.0
# 1   25      14309408        751.0
# 2   15      14309408        751.0
# 3   15      14541708        804.0
# 4   20      14541708        804.0

# %%
## Ratings distribution

df['rating'].value_counts()
# Out:
# 5.0    1220
# 4.0     495
# 3.0     123
# 2.0      28
# 1.0       8
# Name: rating, dtype: int64

# %%
df['user_id'].nunique()
# Out:
# 755

# %%
df['item_id_new'].nunique()
# Out:
# 797

# %% [markdown]
# <div class='alert alert-danger'>
# #### Using the Surprise module
# - load dataset from pandas dataframe using `Dataset.load_from_df`
#
# #### Algorithms to compare:
# - `NormalPredictor`: predicts random rating based on training set which is assumed to be normally distributed
# - `BaselineOnly`: predicts the baseline estimate for a given user and given item
# - `Slope One`: factors in items that a user liked separately from items that a user disliked (by computing the average difference between ratings of one item and another for users who rated both)
# - `Co-clustering`: simultaneous clustering of users and items
#
# **Neighborhood collaborative filtering (CF)**:
# - `KNNBasic`: basic nearest neighbors CF algorithm
# - `KNNWithMeans`: takes into account the mean ratings of each user
# - `KNNWithZScore`: takes into account the z-score normalization of each user
# - `KNNBaseline`: takes into account a baseline rating
#
# **Matrix factorization CF**:
# - `SVD`: singular value decomposition is equivalent to [Probabilistic Matrix Factorization, PMF](http://papers.nips.cc/paper/3208-probabilistic-matrix-factorization.pdf) if baselines are not used
# - `SVDpp or SVD++`: takes into account implicit ratings
# - `NMF`: non-negative matrix factorization
#
# #### Model selection:
# - manually split data into training set and test set (80-20)
# - use `cross_validate` to select model with lowest RSME score
# - use `GridSearchCV` to tune hyperparameters for ratings prediction

# %%
## create reader and load specific columns from dataframe into surprise

reader = Reader(rating_scale=(1,5))

data = Dataset.load_from_df(df[['user_id','item_id_new','rating']], reader)

data1 = Dataset.load_from_df(df[['user_id','item_id_new','rating']], reader)

# %% [markdown]
# <div class='alert alert-warning'>
# #### [manually split data](https://surprise.readthedocs.io/en/stable/FAQ.html#how-to-save-some-data-for-unbiased-accuracy-estimation) into training set and test set

# %%
raw_ratings = data.raw_ratings

random.shuffle(raw_ratings)

# set training set as 80% of the data, test set as 20%
threshold = int(0.8 * len(raw_ratings))

train_raw_ratings = raw_ratings[:threshold]
test_raw_ratings = raw_ratings[threshold:]

data.raw_ratings = train_raw_ratings

# %% [markdown]
# <div class='alert alert-warning'>
# #### compare algorithms using cross validation and pre-defined training set (80%)
# - using metrics: `RMSE`, `MAE`

# %%
comparison = []

algos = [NormalPredictor(), BaselineOnly(), SlopeOne(), CoClustering(),\
         KNNBasic(), KNNWithMeans(), KNNWithZScore(), KNNBaseline(),\
         SVD(), SVDpp(), NMF()]

for algorithm in algos:
    score = cross_validate(algorithm, data, measures=['RMSE','MAE'],\
                             cv=5, verbose=False)
    
    result = pd.DataFrame.from_dict(score).mean(axis=0)
    result = result.append(pd.Series([str(algorithm).split(' ')[0].\
                                      split('.')[-1]],\
                                     index=['Algorithm']))
    comparison.append(result)
# Out:
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
pd.DataFrame(comparison).set_index('Algorithm').\
sort_values('test_rmse',ascending=True)
# Out:
#                  test_rmse  test_mae  fit_time  test_time
# Algorithm
# BaselineOnly      0.714146  0.584842  0.004355   0.001962
# SVDpp             0.718464  0.579511  0.220891   0.005578
# KNNBaseline       0.718990  0.586001  0.013507   0.004410
# SVD               0.719678  0.581727  0.090749   0.033936
# KNNBasic          0.721262  0.591965  0.014676   0.007232
# KNNWithMeans      0.804141  0.587433  0.018860   0.003605
# KNNWithZScore     0.812296  0.581733  0.054549   0.004906
# SlopeOne          0.817517  0.587382  0.018998   0.002565
# CoClustering      0.874650  0.630948  0.166080   0.001939
# NormalPredictor   0.906028  0.676088  0.002189   0.005502
# NMF               1.052386  0.838200  0.198247   0.002934

# %% [markdown]
# <div class='alert alert-danger'>
# #### use the 4 best algorithms to get predictions for existing testset ratings:
# - `BaselineOnly()`, `SVDpp()`, `SVD()`, `KNNWithZScore()`
# - create dataframe for predictions of existing testset ratings
# - note: lower RMSE/MAE is better

# %%
def get_items(user_id):
    """ returns the number of items rated by a given user
    args: 
      uid: the 'raw' id of the user
    """
    try:
        return len(trainset.ur[trainset.to_inner_uid(user_id)])
            # to_inner_uid() converts raw user id to inner id

    except ValueError: # user was not part of the trainset
        return 0
    
def get_users(item_id):
    """ returns number of users that have rated a given item
    args:
      iid: the raw id of the item
    """
    try: 
        return len(trainset.ir[trainset.to_inner_iid(item_id)])
            # to_inner_iid() converts raw item id to inner id
    except ValueError:
        return 0

# %% [markdown]
# #### use GridSearch to find the best parameters for SVDpp and SVD
#
# ```Python
# param_grid = {'n_epochs': [15,25],'lr_all': [0.003, 0.005, 0.007],\
#               'reg_all': [0.02, 0.06, 0.1]}
#
# gs = GridSearchCV(SVDpp, param_grid, measures=['rmse', 'mae'],\
#                   cv=3, joblib_verbose=100)
# gs.fit(data1)
# print('best parameters for SVDpp: ', gs.best_params['rmse'])
#
# gs1 = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'],\
#                    cv=3, joblib_verbose=100)
# gs1.fit(data1)
# print('best parameters for SVD: ', gs1.best_params['rmse'])
# ```
# - best parameters for SVDpp: {**'n_epochs': 15, 'lr_all': 0.005, 'reg_all': 0.02**}
# - best parameters for SVD: {**'n_epochs': 15, 'lr_all': 0.007, 'reg_all': 0.1**}

# %% [markdown]
# ### predict using SVDpp

# %%
# fit SVDpp on training set

trainset = data.build_full_trainset()

algo2 = SVDpp(n_epochs=15,lr_all=0.005,reg_all=0.02)
algo2.fit(trainset)

predictions2_biased = algo2.test(trainset.build_testset())
print('Biased accuracy on training set (SVDpp): ', end='   ')
accuracy.rmse(predictions2_biased)

###########################################################
testset = data.construct_testset(test_raw_ratings)
predictions2_unbiased = algo2.test(testset)
print('Unbiased accuracy on test set (SVDpp): ', end='   ')
accuracy.rmse(predictions2_unbiased)
# Out:
# Biased accuracy on training set (SVDpp):    RMSE: 0.5889
# Unbiased accuracy on test set (SVDpp):    RMSE: 0.7276
# 0.7275631438973952

# %%
# checking that the train-test split is indeed 80-20

print('length of the train set: ',trainset.n_ratings)
print('length of the test set: ',len(testset))
# Out:
# length of the train set:  1499
# length of the test set:  375

# %%
## ## top 10 best and worst predictions for the testset using SVDpp

df_SVDpp = pd.DataFrame(predictions2_unbiased, columns=['uid','iid','actual rating',\
                                                        'estimated rating','details'])
df_SVDpp['number of items for target user'] = df_SVDpp['uid'].apply(get_items)
df_SVDpp['number of users for target item'] = df_SVDpp['iid'].apply(get_users)
df_SVDpp['error'] = abs(df_SVDpp['estimated rating'] - df_SVDpp['actual rating'])

Best_predictions_SVDpp = df_SVDpp.sort_values(by='error')[:10]
Best_predictions_SVDpp
# Out:
#         uid      iid  actual rating  estimated rating  \
# 271  995412     72.0            4.0          3.880957
# 207  327294  19753.0            4.0          4.127474
# 208  172691  11507.0            5.0          4.840355
# 175  290985     65.0            5.0          4.836506
# 94   327294  16609.0            4.0          4.175011
# 132  603079  12630.0            5.0          4.815626
# 279  116347    540.0            5.0          4.803411
# 62   796263   8070.0            5.0          4.786825
# 56   472209  11507.0            5.0          4.778710
# 75   214199  23058.0            5.0          4.767775
#
#                        details  number of items for target user  \
# 271  {'was_impossible': False}                                3
# 207  {'was_impossible': False}                                3
# 208  {'was_impossible': False}                                4
# 175  {'was_impossible': False}                                5
# 94   {'was_impossible': False}                                3
# 132  {'was_impossible': False}                                4
# 279  {'was_impossible': False}                                1
# 62   {'was_impossible': False}                                3
# 56   {'was_impossible': False}                                2
# 75   {'was_impossible': False}                                4
#
#      number of users for target item     error
# 271                                6  0.119043
# 207                                1  0.127474
# 208                                7  0.159645
# 175                                3  0.163494
# 94                                 1  0.175011
# 132                                3  0.184374
# 279                                1  0.196589
# 62                                 8  0.213175
# 56                                 7  0.221290
# 75                                 2  0.232225

# %%
Worst_predictions_SVDpp = df_SVDpp.sort_values(by='error')[-10:]
Worst_predictions_SVDpp
# Out:
#         uid      iid  actual rating  estimated rating  \
# 266  273767  19055.0            3.0          4.650265
# 300  884651   3572.0            3.0          4.666265
# 237   19177   1739.0            3.0          4.734435
# 329  327294   7743.0            2.0          4.169621
# 286  645325    169.0            2.0          4.513448
# 19   365674    202.0            2.0          4.565327
# 212  836131   9607.0            2.0          4.572519
# 189   92826    531.0            2.0          4.578075
# 348   31844  11449.0            2.0          4.641362
# 308  343315    771.0            1.0          4.577056
#
#                        details  number of items for target user  \
# 266  {'was_impossible': False}                                6
# 300  {'was_impossible': False}                                4
# 237  {'was_impossible': False}                                8
# 329  {'was_impossible': False}                                3
# 286  {'was_impossible': False}                                0
# 19   {'was_impossible': False}                                3
# 212  {'was_impossible': False}                                0
# 189  {'was_impossible': False}                                1
# 348  {'was_impossible': False}                                1
# 308  {'was_impossible': False}                                1
#
#      number of users for target item     error
# 266                                5  1.650265
# 300                                1  1.666265
# 237                                2  1.734435
# 329                                1  2.169621
# 286                                4  2.513448
# 19                                 1  2.565327
# 212                                1  2.572519
# 189                                0  2.578075
# 348                                2  2.641362
# 308                                0  3.577056

# %% [markdown]
# <div class='alert alert-warning'>
# #### get top-N recommendations for each user
#
# - first train each algorithm on the whole dataset
# - then predict all the **ratings for user-item pairs that are not in** the dataset
# - retrieve top-N predictions for each user

# %%
## using get_top_n function from surprise library

from collections import defaultdict

def get_top_n(predictions, n):
    ''' 
    Return the top-N recommendation for each user from set of predictions.
        
    Args:
    predictions(list of Prediction objects): The list of predictions,
        as returned by the test method of an algorithm.
    n(int): The number of recommendation to output for each user. 
    Default is 10.

    Returns:
    A dict where keys are user (raw) ids and values are lists of
        tuples: [(raw item id, rating estimation), ...] of size n.
    '''
        
    # First map the predictions to each user.
    top_n = defaultdict(list)
    
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the 
        # k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n


def get_categ(itemID):
    ''' 
    Returns item category for a given itemID
    '''
    category = df[df['item_id_new']==itemID]['category'].values[0]
    
    return category


def get_existing(userID):
    ''' 
    Returns list of at most 10 random items that user has rented
    '''
    existing = df[df['user_id']==userID]['item_id_new']
    exdict = {}
    if len(existing) < 10:
        exist = list(df[df['user_id']==userID]['item_id_new'].\
                     sample(n=len(existing), random_state=1))
        exdict[userID] = [(a, get_categ(a)) for a in exist]
    else:
        exist = list(df[df['user_id']==userID]['item_id_new'].\
                     sample(n=10, random_state=1))
        exdict[userID] = [(a, get_categ(a)) for a in exist]
    return exdict

# %%
## train SVDpp algorithm on the whole dataset

trainset = data1.build_full_trainset()
algo = SVDpp(n_epochs=15,lr_all=0.005,reg_all=0.02)
algo.fit(trainset)

## predict all ratings (for user-item pairs) that are not in the train set
testset = trainset.build_anti_testset()
predictions_SVDpp = algo.test(testset)
accuracy.rmse(predictions_SVDpp)

topNPredicted_SVDpp = get_top_n(predictions_SVDpp, 10)

SVDpp_recc_dict = {}
SVDpp_exist_dict = {}

## print existing and recommended items for each user:
i=0
for uid, user_ratings in topNPredicted_SVDpp.items():
    exitem = get_existing(uid)
    
    print("Random 10 rented items for user {0}: {1}".\
          format(uid, list(a for a in exitem.values())[0]))
    SVDpp_exist_dict[uid] = list(a for a in exitem.values())[0]
    print()
    
    SVDpp_recc_dict[uid] = [(iid,get_categ(iid)) for (iid,_) in user_ratings]
    print('Top 10 recommended new items for user {0}: {1}'.\
          format(uid, [(iid,get_categ(iid)) for (iid,_) in user_ratings]))
    print('-------------------------------------------------------------')
    
    i+=1
print('Number of recommended item sets (SVDpp):', i)
# Out:
# RMSE: 0.1229
# Random 10 rented items for user 610914: [(751.0, 'dress')]
#
# Top 10 recommended new items for user 610914: [(22933.0, 'dress'), (16009.0, 'maxi'), (10373.0, 'dress'), (17444.0, 'gown'), (4816.0, 'sheath'), (16715.0, 'dress'), (11507.0, 'dress'), (1551.0, 'sheath'), (17879.0, 'dress'), (28598.0, 'blazer')]
# -------------------------------------------------------------
# Random 10 rented items for user 53519: [(751.0, 'dress'), (8003.0, 'dress')]
#
# Top 10 recommended new items for user 53519: [(27357.0, 'blazer'), (8536.0, 'dress'), (11966.0, 'dress'), (17879.0, 'dress'), (7637.0, 'dress'), (11507.0, 'dress'), (1176.0, 'dress'), (528.0, 'dress'), (1375.0, 'dress'), (386.0, 'gown')]
# -------------------------------------------------------------
# Random 10 rented items for user 470639: [(414.0, 'gown'), (528.0, 'dress'), (22588.0, 'dress'), (751.0, 'dress'), (878.0, 'dress')]
#
# Top 10 recommended new items for user 470639: [(11507.0, 'dress'), (13679.0, 'dress'), (11966.0, 'dress'), (972.0, 'sheath'), (544.0, 'sheath'), (27762.0, 'jumpsuit'), (1323.0, 'gown'), (4783.0, 'dress'), (17789.0, 'sheath'), (9499.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 276186: [(804.0, 'dress')]
#
# Top 10 recommended new items for user 276186: [(28598.0, 'blazer'), (5784.0, 'dress'), (1323.0, 'gown'), (22808.0, 'dress'), (22127.0, 'gown'), (27357.0, 'blazer'), (11507.0, 'dress'), (19593.0, 'gown'), (10373.0, 'dress'), (2273.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 748397: [(17879.0, 'dress'), (800.0, 'sheath'), (5093.0, 'dress'), (804.0, 'dress'), (26856.0, 'jumpsuit')]
#
# Top 10 recommended new items for user 748397: [(16828.0, 'dress'), (27357.0, 'blazer'), (19787.0, 'dress'), (1094.0, 'dress'), (4816.0, 'sheath'), (9605.0, 'dress'), (29042.0, 'jacket'), (212.0, 'gown'), (288.0, 'dress'), (4602.0, 'gown')]
# -------------------------------------------------------------
# Random 10 rented items for user 856829: [(9499.0, 'dress'), (1276.0, 'mini'), (804.0, 'dress'), (545.0, 'sheath')]
#
# Top 10 recommended new items for user 856829: [(11966.0, 'dress'), (8852.0, 'dress'), (24585.0, 'jumpsuit'), (11507.0, 'dress'), (12154.0, 'gown'), (1534.0, 'dress'), (556.0, 'gown'), (2253.0, 'dress'), (1416.0, 'dress'), (10373.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 990544: [(804.0, 'dress')]
#
# Top 10 recommended new items for user 990544: [(16009.0, 'maxi'), (10373.0, 'dress'), (1323.0, 'gown'), (17879.0, 'dress'), (22808.0, 'dress'), (11966.0, 'dress'), (22588.0, 'dress'), (1614.0, 'maxi'), (27357.0, 'blazer'), (11507.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 214108: [(8157.0, 'dress')]
#
# Top 10 recommended new items for user 214108: [(1604.0, 'dress'), (23305.0, 'sheath'), (19593.0, 'gown'), (1416.0, 'dress'), (133.0, 'gown'), (769.0, 'dress'), (2540.0, 'dress'), (524.0, 'dress'), (14158.0, 'shift'), (1388.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 503301: [(524.0, 'dress'), (1387.0, 'dress'), (8157.0, 'dress'), (1450.0, 'dress')]
#
# Top 10 recommended new items for user 503301: [(20712.0, 'sheath'), (27357.0, 'blazer'), (11507.0, 'dress'), (4816.0, 'sheath'), (779.0, 'gown'), (39.0, 'gown'), (133.0, 'gown'), (11966.0, 'dress'), (216.0, 'gown'), (10883.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 574571: [(16499.0, 'dress'), (1005.0, 'mini'), (8157.0, 'dress'), (1602.0, 'dress')]
#
# Top 10 recommended new items for user 574571: [(4816.0, 'sheath'), (17879.0, 'dress'), (23912.0, 'legging'), (19787.0, 'dress'), (1375.0, 'dress'), (29042.0, 'jacket'), (11966.0, 'dress'), (7756.0, 'dress'), (20712.0, 'sheath'), (27357.0, 'blazer')]
# -------------------------------------------------------------
# Random 10 rented items for user 407375: [(1304.0, 'gown')]
#
# Top 10 recommended new items for user 407375: [(4816.0, 'sheath'), (218.0, 'gown'), (17444.0, 'gown'), (67.0, 'dress'), (1179.0, 'dress'), (2540.0, 'dress'), (14597.0, 'dress'), (528.0, 'dress'), (27119.0, 'jumpsuit'), (14429.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 78488: [(584.0, 'gown'), (4816.0, 'sheath'), (1304.0, 'gown'), (20188.0, 'shift')]
#
# Top 10 recommended new items for user 78488: [(1614.0, 'maxi'), (524.0, 'dress'), (11507.0, 'dress'), (417.0, 'gown'), (17789.0, 'sheath'), (10883.0, 'sheath'), (27357.0, 'blazer'), (218.0, 'gown'), (7328.0, 'dress'), (7756.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 871986: [(24183.0, 'romper')]
#
# Top 10 recommended new items for user 871986: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress'), (2171.0, 'dress'), (27357.0, 'blazer'), (9499.0, 'dress'), (14302.0, 'dress'), (28598.0, 'blazer'), (10883.0, 'sheath'), (171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 290985: [(1204.0, 'gown'), (65.0, 'dress'), (9604.0, 'dress'), (24183.0, 'romper'), (18707.0, 'sheath'), (269.0, 'dress'), (800.0, 'sheath')]
#
# Top 10 recommended new items for user 290985: [(19787.0, 'dress'), (27357.0, 'blazer'), (29042.0, 'jacket'), (1323.0, 'gown'), (19741.0, 'sheath'), (22588.0, 'dress'), (15859.0, 'maxi'), (11966.0, 'dress'), (20411.0, 'dress'), (18950.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 26196: [(3886.0, 'dress'), (212.0, 'gown'), (2159.0, 'dress'), (24183.0, 'romper'), (28976.0, 'romper'), (15587.0, 'gown'), (971.0, 'sheath')]
#
# Top 10 recommended new items for user 26196: [(11507.0, 'dress'), (12154.0, 'gown'), (1241.0, 'dress'), (2171.0, 'dress'), (27119.0, 'jumpsuit'), (255.0, 'gown'), (29558.0, 'jumpsuit'), (288.0, 'dress'), (24585.0, 'jumpsuit'), (1005.0, 'mini')]
# -------------------------------------------------------------
# Random 10 rented items for user 166307: [(18254.0, 'dress'), (72.0, 'dress'), (16609.0, 'dress'), (24183.0, 'romper'), (19742.0, 'sheath'), (539.0, 'sheath')]
#
# Top 10 recommended new items for user 166307: [(13679.0, 'dress'), (11507.0, 'dress'), (11966.0, 'dress'), (17789.0, 'sheath'), (22127.0, 'gown'), (544.0, 'sheath'), (5976.0, 'print'), (19593.0, 'gown'), (23304.0, 'sheath'), (22892.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 234006: [(418.0, 'gown'), (14306.0, 'dress'), (170.0, 'dress'), (29560.0, 'jumpsuit')]
#
# Top 10 recommended new items for user 234006: [(11507.0, 'dress'), (27119.0, 'jumpsuit'), (10883.0, 'sheath'), (11966.0, 'dress'), (24585.0, 'jumpsuit'), (27357.0, 'blazer'), (8070.0, 'dress'), (27762.0, 'jumpsuit'), (19787.0, 'dress'), (216.0, 'gown')]
# -------------------------------------------------------------
# Random 10 rented items for user 408945: [(13488.0, 'sheath'), (137.0, 'gown'), (12669.0, 'dress'), (170.0, 'dress'), (274.0, 'dress'), (1264.0, 'gown'), (701.0, 'gown')]
#
# Top 10 recommended new items for user 408945: [(11507.0, 'dress'), (23058.0, 'dress'), (528.0, 'dress'), (16830.0, 'dress'), (1369.0, 'dress'), (23303.0, 'sheath'), (27119.0, 'jumpsuit'), (21408.0, 'dress'), (27762.0, 'jumpsuit'), (17879.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 480020: [(170.0, 'dress'), (85.0, 'dress'), (7637.0, 'dress')]
#
# Top 10 recommended new items for user 480020: [(27119.0, 'jumpsuit'), (18950.0, 'dress'), (972.0, 'sheath'), (212.0, 'gown'), (1020.0, 'gown'), (23303.0, 'sheath'), (19306.0, 'gown'), (27357.0, 'blazer'), (12385.0, 'dress'), (10373.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 916978: [(170.0, 'dress'), (4783.0, 'dress'), (567.0, 'gown')]
#
# Top 10 recommended new items for user 916978: [(11507.0, 'dress'), (11966.0, 'dress'), (27119.0, 'jumpsuit'), (10373.0, 'dress'), (19315.0, 'sheath'), (216.0, 'gown'), (24585.0, 'jumpsuit'), (29558.0, 'jumpsuit'), (18264.0, 'dress'), (19476.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 971553: [(170.0, 'dress'), (5783.0, 'dress'), (523.0, 'shift')]
#
# Top 10 recommended new items for user 971553: [(11507.0, 'dress'), (490.0, 'gown'), (9794.0, 'dress'), (22934.0, 'dress'), (17879.0, 'dress'), (27762.0, 'jumpsuit'), (544.0, 'sheath'), (19769.0, 'dress'), (989.0, 'gown'), (467.0, 'gown')]
# -------------------------------------------------------------
# Random 10 rented items for user 526586: [(170.0, 'dress')]
#
# Top 10 recommended new items for user 526586: [(13679.0, 'dress'), (22892.0, 'sheath'), (972.0, 'sheath'), (11507.0, 'dress'), (19249.0, 'maxi'), (11966.0, 'dress'), (544.0, 'sheath'), (100.0, 'gown'), (8391.0, 'sheath'), (27357.0, 'blazer')]
# -------------------------------------------------------------
# Random 10 rented items for user 648369: [(170.0, 'dress'), (12289.0, 'dress')]
#
# Top 10 recommended new items for user 648369: [(7637.0, 'dress'), (27357.0, 'blazer'), (8159.0, 'dress'), (11966.0, 'dress'), (10502.0, 'dress'), (8003.0, 'dress'), (537.0, 'sheath'), (878.0, 'dress'), (17879.0, 'dress'), (23412.0, 'shift')]
# -------------------------------------------------------------
# Random 10 rented items for user 339506: [(170.0, 'dress'), (710.0, 'dress'), (2560.0, 'maxi')]
# Top 10 recommended new items for user 339506: [(11966.0, 'dress'), (27357.0, 'blazer'), (8031.0, 'dress'), (8159.0, 'dress'), (335.0, 'gown'), (27119.0, 'jumpsuit'), (22655.0, 'sheath'), (7637.0, 'dress'), (975.0, 'sheath'), (540.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 571227: [(170.0, 'dress')]
#
# Top 10 recommended new items for user 571227: [(972.0, 'sheath'), (13679.0, 'dress'), (19306.0, 'gown'), (27762.0, 'jumpsuit'), (27119.0, 'jumpsuit'), (212.0, 'gown'), (17925.0, 'sheath'), (11507.0, 'dress'), (23303.0, 'sheath'), (11966.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 968500: [(29560.0, 'jumpsuit'), (169.0, 'dress')]
#
# Top 10 recommended new items for user 968500: [(2501.0, 'dress'), (2540.0, 'dress'), (1604.0, 'dress'), (27357.0, 'blazer'), (13679.0, 'dress'), (6980.0, 'dress'), (4597.0, 'dress'), (12630.0, 'dress'), (212.0, 'gown'), (11966.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 806600: [(14306.0, 'dress')]
#
# Top 10 recommended new items for user 806600: [(11507.0, 'dress'), (12154.0, 'gown'), (19787.0, 'dress'), (10883.0, 'sheath'), (65.0, 'dress'), (39.0, 'gown'), (27357.0, 'blazer'), (27119.0, 'jumpsuit'), (4816.0, 'sheath'), (1614.0, 'maxi')]
# -------------------------------------------------------------
# Random 10 rented items for user 84770: [(14306.0, 'dress'), (21954.0, 'shift'), (10377.0, 'dress')]
#
# Top 10 recommended new items for user 84770: [(27119.0, 'jumpsuit'), (19787.0, 'dress'), (20411.0, 'dress'), (137.0, 'gown'), (65.0, 'dress'), (4816.0, 'sheath'), (11507.0, 'dress'), (22654.0, 'sheath'), (2560.0, 'maxi'), (10883.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 269712: [(29231.0, 'jumpsuit'), (20951.0, 'sheath'), (1592.0, 'dress'), (11122.0, 'dress'), (21781.0, 'sheath')]
#
# Top 10 recommended new items for user 269712: [(11507.0, 'dress'), (27119.0, 'jumpsuit'), (11966.0, 'dress'), (7637.0, 'dress'), (22034.0, 'dress'), (10883.0, 'sheath'), (13679.0, 'dress'), (19288.0, 'gown'), (8003.0, 'dress'), (19315.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 736692: [(11122.0, 'dress')]
#
# Top 10 recommended new items for user 736692: [(11507.0, 'dress'), (12154.0, 'gown'), (10883.0, 'sheath'), (24585.0, 'jumpsuit'), (101.0, 'gown'), (18954.0, 'dress'), (9605.0, 'dress'), (1241.0, 'dress'), (23304.0, 'sheath'), (12630.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 853733: [(11122.0, 'dress'), (11741.0, 'dress'), (15859.0, 'maxi')]
#
# Top 10 recommended new items for user 853733: [(24585.0, 'jumpsuit'), (11507.0, 'dress'), (22655.0, 'sheath'), (9605.0, 'dress'), (975.0, 'sheath'), (11966.0, 'dress'), (18954.0, 'dress'), (9329.0, 'dress'), (581.0, 'gown'), (12154.0, 'gown')]
# -------------------------------------------------------------
# Random 10 rented items for user 600534: [(11740.0, 'dress'), (26856.0, 'jumpsuit'), (386.0, 'gown'), (11122.0, 'dress'), (14161.0, 'shift'), (526.0, 'dress')]
#
# Top 10 recommended new items for user 600534: [(11507.0, 'dress'), (10883.0, 'sheath'), (544.0, 'sheath'), (9609.0, 'dress'), (9605.0, 'dress'), (536.0, 'sheath'), (21951.0, 'shift'), (172.0, 'dress'), (14303.0, 'dress'), (18954.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 673553: [(11122.0, 'dress'), (1087.0, 'dress')]
#
# Top 10 recommended new items for user 673553: [(11507.0, 'dress'), (2540.0, 'dress'), (467.0, 'gown'), (11966.0, 'dress'), (1458.0, 'sheath'), (18264.0, 'dress'), (815.0, 'gown'), (18707.0, 'sheath'), (1557.0, 'shift'), (1094.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 477583: [(6732.0, 'dress'), (1240.0, 'dress'), (7154.0, 'sheath'), (11122.0, 'dress'), (10885.0, 'sheath')]
#
# Top 10 recommended new items for user 477583: [(28598.0, 'blazer'), (27357.0, 'blazer'), (11507.0, 'dress'), (27068.0, 'skirt'), (14303.0, 'dress'), (524.0, 'dress'), (4816.0, 'sheath'), (11741.0, 'dress'), (1675.0, 'dress'), (12452.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 649434: [(20951.0, 'sheath'), (27119.0, 'jumpsuit')]
#
# Top 10 recommended new items for user 649434: [(11507.0, 'dress'), (11966.0, 'dress'), (22063.0, 'dress'), (10883.0, 'sheath'), (27762.0, 'jumpsuit'), (17789.0, 'sheath'), (1204.0, 'gown'), (24585.0, 'jumpsuit'), (1534.0, 'dress'), (27357.0, 'blazer')]
# -------------------------------------------------------------
# Random 10 rented items for user 560601: [(19288.0, 'gown'), (1368.0, 'dress'), (21848.0, 'dress'), (19596.0, 'gown'), (20951.0, 'sheath'), (1277.0, 'mini'), (29295.0, 'romper'), (22129.0, 'gown')]
#
# Top 10 recommended new items for user 560601: [(528.0, 'dress'), (4779.0, 'dress'), (10882.0, 'sheath'), (17789.0, 'sheath'), (300.0, 'gown'), (19593.0, 'gown'), (537.0, 'sheath'), (19753.0, 'dress'), (22655.0, 'sheath'), (22933.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 941136: [(20951.0, 'sheath'), (203.0, 'dress')]
#
# Top 10 recommended new items for user 941136: [(7637.0, 'dress'), (1614.0, 'maxi'), (22034.0, 'dress'), (11507.0, 'dress'), (528.0, 'dress'), (100.0, 'gown'), (27357.0, 'blazer'), (27762.0, 'jumpsuit'), (753.0, 'dress'), (17789.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 852045: [(20951.0, 'sheath')]
#
# Top 10 recommended new items for user 852045: [(11507.0, 'dress'), (13679.0, 'dress'), (17789.0, 'sheath'), (23304.0, 'sheath'), (7637.0, 'dress'), (528.0, 'dress'), (27762.0, 'jumpsuit'), (11966.0, 'dress'), (1614.0, 'maxi'), (11122.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 399524: [(20951.0, 'sheath'), (72.0, 'dress')]
#
# Top 10 recommended new items for user 399524: [(8003.0, 'dress'), (1604.0, 'dress'), (11507.0, 'dress'), (11966.0, 'dress'), (12630.0, 'dress'), (29558.0, 'jumpsuit'), (83.0, 'dress'), (16807.0, 'dress'), (467.0, 'gown'), (5976.0, 'print')]
# -------------------------------------------------------------
# Random 10 rented items for user 452401: [(20951.0, 'sheath')]
#
# Top 10 recommended new items for user 452401: [(11507.0, 'dress'), (528.0, 'dress'), (300.0, 'gown'), (22892.0, 'sheath'), (537.0, 'sheath'), (27119.0, 'jumpsuit'), (288.0, 'dress'), (12629.0, 'dress'), (19593.0, 'gown'), (18707.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 130782: [(1551.0, 'sheath'), (28447.0, 'jumpsuit'), (29558.0, 'jumpsuit'), (29231.0, 'jumpsuit'), (9408.0, 'sheath')]
#
# Top 10 recommended new items for user 130782: [(528.0, 'dress'), (27119.0, 'jumpsuit'), (19787.0, 'dress'), (22933.0, 'dress'), (537.0, 'sheath'), (407.0, 'gown'), (17879.0, 'dress'), (23303.0, 'sheath'), (14597.0, 'dress'), (65.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 681467: [(1277.0, 'mini'), (9794.0, 'dress'), (1458.0, 'sheath'), (29231.0, 'jumpsuit'), (1452.0, 'dress'), (9501.0, 'dress')]
#
# Top 10 recommended new items for user 681467: [(24585.0, 'jumpsuit'), (9329.0, 'dress'), (12154.0, 'gown'), (11507.0, 'dress'), (27119.0, 'jumpsuit'), (29558.0, 'jumpsuit'), (20411.0, 'dress'), (1241.0, 'dress'), (1616.0, 'maxi'), (662.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 888739: [(12081.0, 'dress'), (19482.0, 'dress'), (29231.0, 'jumpsuit'), (21781.0, 'sheath')]
#
# Top 10 recommended new items for user 888739: [(11507.0, 'dress'), (100.0, 'gown'), (1204.0, 'gown'), (417.0, 'gown'), (24585.0, 'jumpsuit'), (172.0, 'dress'), (22034.0, 'dress'), (27762.0, 'jumpsuit'), (168.0, 'dress'), (22933.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 606187: [(29231.0, 'jumpsuit'), (4816.0, 'sheath')]
#
# Top 10 recommended new items for user 606187: [(27119.0, 'jumpsuit'), (65.0, 'dress'), (10883.0, 'sheath'), (11507.0, 'dress'), (243.0, 'gown'), (27357.0, 'blazer'), (172.0, 'dress'), (1264.0, 'gown'), (13679.0, 'dress'), (16828.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 509041: [(29231.0, 'jumpsuit'), (3391.0, 'sheath')]
#
# Top 10 recommended new items for user 509041: [(11507.0, 'dress'), (4816.0, 'sheath'), (528.0, 'dress'), (22127.0, 'gown'), (14597.0, 'dress'), (22129.0, 'gown'), (544.0, 'sheath'), (101.0, 'gown'), (19769.0, 'dress'), (14163.0, 'shift')]
# -------------------------------------------------------------
# Random 10 rented items for user 691468: [(1604.0, 'dress'), (8069.0, 'dress'), (1235.0, 'dress'), (27529.0, 'romper'), (22034.0, 'dress'), (2557.0, 'maxi'), (1714.0, 'dress'), (22893.0, 'sheath'), (19476.0, 'dress'), (23057.0, 'dress')]
#
# Top 10 recommended new items for user 691468: [(528.0, 'dress'), (386.0, 'gown'), (4779.0, 'dress'), (12291.0, 'dress'), (11507.0, 'dress'), (4783.0, 'dress'), (1503.0, 'dress'), (7326.0, 'dress'), (17879.0, 'dress'), (9946.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 791274: [(27068.0, 'skirt'), (869.0, 'shift'), (21781.0, 'sheath'), (525.0, 'dress')]
#
# Top 10 recommended new items for user 791274: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (216.0, 'gown'), (8003.0, 'dress'), (2560.0, 'maxi'), (8094.0, 'dress'), (67.0, 'dress'), (10883.0, 'sheath'), (11741.0, 'dress'), (4816.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 822475: [(70.0, 'dress'), (7748.0, 'sheath'), (11965.0, 'dress'), (1592.0, 'dress'), (27635.0, 'suit'), (23303.0, 'sheath'), (21013.0, 'sheath')]
#
# Top 10 recommended new items for user 822475: [(22892.0, 'sheath'), (17925.0, 'sheath'), (16830.0, 'dress'), (12629.0, 'dress'), (8003.0, 'dress'), (556.0, 'gown'), (1514.0, 'maxi'), (20408.0, 'dress'), (17879.0, 'dress'), (27119.0, 'jumpsuit')]
# -------------------------------------------------------------
# Random 10 rented items for user 402094: [(6133.0, 'dress'), (28929.0, 'jumpsuit'), (1714.0, 'dress'), (1592.0, 'dress'), (1388.0, 'dress'), (1405.0, 'dress'), (2534.0, 'dress')]
#
# Top 10 recommended new items for user 402094: [(11507.0, 'dress'), (537.0, 'sheath'), (27119.0, 'jumpsuit'), (27357.0, 'blazer'), (7926.0, 'gown'), (22034.0, 'dress'), (28598.0, 'blazer'), (12629.0, 'dress'), (11966.0, 'dress'), (4179.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 434928: [(4779.0, 'dress'), (1074.0, 'dress')]
#
# Top 10 recommended new items for user 434928: [(11507.0, 'dress'), (9609.0, 'dress'), (4816.0, 'sheath'), (18954.0, 'dress'), (1087.0, 'dress'), (30420.0, 'romper'), (8094.0, 'dress'), (1614.0, 'maxi'), (9605.0, 'dress'), (7926.0, 'gown')]
# -------------------------------------------------------------
# Random 10 rented items for user 691606: [(12140.0, 'sheath'), (1135.0, 'gown'), (19483.0, 'dress'), (14602.0, 'dress'), (4779.0, 'dress'), (1094.0, 'dress'), (1235.0, 'dress'), (20727.0, 'dress')]
#
# Top 10 recommended new items for user 691606: [(21408.0, 'dress'), (20408.0, 'dress'), (4783.0, 'dress'), (27119.0, 'jumpsuit'), (16830.0, 'dress'), (9408.0, 'sheath'), (67.0, 'dress'), (16503.0, 'dress'), (1264.0, 'gown'), (18709.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 509541: [(20720.0, 'dress'), (1764.0, 'dress'), (4779.0, 'dress'), (1367.0, 'dress')]
#
# Top 10 recommended new items for user 509541: [(11507.0, 'dress'), (17879.0, 'dress'), (9609.0, 'dress'), (4816.0, 'sheath'), (10883.0, 'sheath'), (22655.0, 'sheath'), (9605.0, 'dress'), (18954.0, 'dress'), (14303.0, 'dress'), (12151.0, 'gown')]
# -------------------------------------------------------------
# Random 10 rented items for user 998194: [(4779.0, 'dress'), (1006.0, 'mini')]
#
# Top 10 recommended new items for user 998194: [(14158.0, 'shift'), (2540.0, 'dress'), (39.0, 'gown'), (4816.0, 'sheath'), (769.0, 'dress'), (11507.0, 'dress'), (2171.0, 'dress'), (17789.0, 'sheath'), (7155.0, 'sheath'), (8094.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 214703: [(921.0, 'gown'), (27357.0, 'blazer'), (4779.0, 'dress'), (22034.0, 'dress')]
#
# Top 10 recommended new items for user 214703: [(39.0, 'gown'), (10883.0, 'sheath'), (19787.0, 'dress'), (13488.0, 'sheath'), (2560.0, 'maxi'), (528.0, 'dress'), (335.0, 'gown'), (11507.0, 'dress'), (18707.0, 'sheath'), (65.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 950400: [(1690.0, 'dress'), (1614.0, 'maxi'), (1258.0, 'gown'), (4779.0, 'dress'), (814.0, 'gown')]
#
# Top 10 recommended new items for user 950400: [(1416.0, 'dress'), (39.0, 'gown'), (1710.0, 'dress'), (779.0, 'gown'), (29558.0, 'jumpsuit'), (23304.0, 'sheath'), (17925.0, 'sheath'), (20759.0, 'gown'), (18707.0, 'sheath'), (2500.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 593000: [(4779.0, 'dress'), (19683.0, 'sheath'), (479.0, 'dress')]
#
# Top 10 recommended new items for user 593000: [(1204.0, 'gown'), (9499.0, 'dress'), (172.0, 'dress'), (13679.0, 'dress'), (11507.0, 'dress'), (23303.0, 'sheath'), (4783.0, 'dress'), (1029.0, 'gown'), (16009.0, 'maxi'), (223.0, 'gown')]
# -------------------------------------------------------------
# Random 10 rented items for user 146524: [(4779.0, 'dress'), (19306.0, 'gown')]
#
# Top 10 recommended new items for user 146524: [(39.0, 'gown'), (528.0, 'dress'), (4816.0, 'sheath'), (9946.0, 'dress'), (2560.0, 'maxi'), (10882.0, 'sheath'), (676.0, 'gown'), (17879.0, 'dress'), (1087.0, 'dress'), (7326.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 41413: [(20409.0, 'dress'), (20458.0, 'dress')]
#
# Top 10 recommended new items for user 41413: [(528.0, 'dress'), (11507.0, 'dress'), (27119.0, 'jumpsuit'), (2171.0, 'dress'), (288.0, 'dress'), (14597.0, 'dress'), (2560.0, 'maxi'), (7684.0, 'dress'), (22933.0, 'dress'), (4816.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 812433: [(519.0, 'shift'), (2159.0, 'dress'), (14162.0, 'shift'), (20409.0, 'dress'), (9943.0, 'dress'), (709.0, 'dress')]
#
# Top 10 recommended new items for user 812433: [(11507.0, 'dress'), (11966.0, 'dress'), (27119.0, 'jumpsuit'), (27357.0, 'blazer'), (16830.0, 'dress'), (20411.0, 'dress'), (537.0, 'sheath'), (14158.0, 'shift'), (17444.0, 'gown'), (17426.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 722597: [(20458.0, 'dress')]
#
# Top 10 recommended new items for user 722597: [(11507.0, 'dress'), (27119.0, 'jumpsuit'), (11966.0, 'dress'), (1020.0, 'gown'), (537.0, 'sheath'), (8070.0, 'dress'), (10883.0, 'sheath'), (528.0, 'dress'), (18707.0, 'sheath'), (12925.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 334479: [(20458.0, 'dress')]
#
# Top 10 recommended new items for user 334479: [(13679.0, 'dress'), (11966.0, 'dress'), (7637.0, 'dress'), (11507.0, 'dress'), (544.0, 'sheath'), (4608.0, 'gown'), (27762.0, 'jumpsuit'), (10883.0, 'sheath'), (481.0, 'dress'), (23304.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 172028: [(20458.0, 'dress'), (18650.0, 'dress')]
#
# Top 10 recommended new items for user 172028: [(11966.0, 'dress'), (27119.0, 'jumpsuit'), (11507.0, 'dress'), (24585.0, 'jumpsuit'), (10882.0, 'sheath'), (537.0, 'sheath'), (1005.0, 'mini'), (22933.0, 'dress'), (83.0, 'dress'), (16807.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 472209: [(20458.0, 'dress'), (110.0, 'gown'), (11507.0, 'dress')]
#
# Top 10 recommended new items for user 472209: [(27119.0, 'jumpsuit'), (11966.0, 'dress'), (27068.0, 'skirt'), (1020.0, 'gown'), (28598.0, 'blazer'), (528.0, 'dress'), (23304.0, 'sheath'), (14302.0, 'dress'), (10883.0, 'sheath'), (27357.0, 'blazer')]
# -------------------------------------------------------------
# Random 10 rented items for user 849315: [(14.0, 'gown')]
#
# Top 10 recommended new items for user 849315: [(22892.0, 'sheath'), (27762.0, 'jumpsuit'), (11966.0, 'dress'), (23303.0, 'sheath'), (17925.0, 'sheath'), (13679.0, 'dress'), (24585.0, 'jumpsuit'), (2556.0, 'maxi'), (19306.0, 'gown'), (22808.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 32925: [(29294.0, 'romper'), (2159.0, 'dress'), (2273.0, 'dress'), (16162.0, 'dress'), (9295.0, 'gown'), (22933.0, 'dress'), (11449.0, 'dress'), (16807.0, 'dress')]
#
# Top 10 recommended new items for user 32925: [(11507.0, 'dress'), (27357.0, 'blazer'), (526.0, 'dress'), (22034.0, 'dress'), (22220.0, 'sheath'), (11966.0, 'dress'), (528.0, 'dress'), (8536.0, 'dress'), (27119.0, 'jumpsuit'), (16009.0, 'maxi')]
# -------------------------------------------------------------
# Random 10 rented items for user 78104: [(2273.0, 'dress'), (1177.0, 'dress'), (1405.0, 'dress')]
#
# Top 10 recommended new items for user 78104: [(39.0, 'gown'), (21951.0, 'shift'), (10883.0, 'sheath'), (11507.0, 'dress'), (7637.0, 'dress'), (27357.0, 'blazer'), (6980.0, 'dress'), (13679.0, 'dress'), (11966.0, 'dress'), (65.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 536638: [(2159.0, 'dress')]
#
# Top 10 recommended new items for user 536638: [(528.0, 'dress'), (11507.0, 'dress'), (7637.0, 'dress'), (1614.0, 'maxi'), (17879.0, 'dress'), (22034.0, 'dress'), (19288.0, 'gown'), (18707.0, 'sheath'), (407.0, 'gown'), (27357.0, 'blazer')]
# -------------------------------------------------------------
# Random 10 rented items for user 835431: [(12080.0, 'dress'), (7756.0, 'dress'), (11449.0, 'dress'), (6979.0, 'dress')]
#
# Top 10 recommended new items for user 835431: [(13679.0, 'dress'), (2276.0, 'dress'), (27762.0, 'jumpsuit'), (7637.0, 'dress'), (528.0, 'dress'), (20197.0, 'dress'), (556.0, 'gown'), (4816.0, 'sheath'), (17789.0, 'sheath'), (11507.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 31844: [(11449.0, 'dress'), (7637.0, 'dress')]
#
# Top 10 recommended new items for user 31844: [(27357.0, 'blazer'), (12630.0, 'dress'), (8003.0, 'dress'), (1020.0, 'gown'), (27119.0, 'jumpsuit'), (11966.0, 'dress'), (42.0, 'gown'), (13679.0, 'dress'), (23900.0, 'romper'), (540.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 134802: [(21843.0, 'dress'), (13679.0, 'dress'), (22933.0, 'dress'), (7683.0, 'dress')]
#
# Top 10 recommended new items for user 134802: [(4816.0, 'sheath'), (27357.0, 'blazer'), (17879.0, 'dress'), (1614.0, 'maxi'), (23912.0, 'legging'), (11507.0, 'dress'), (2273.0, 'dress'), (22808.0, 'dress'), (9408.0, 'sheath'), (528.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 597738: [(22933.0, 'dress')]
# Top 10 recommended new items for user 597738: [(27357.0, 'blazer'), (28598.0, 'blazer'), (11966.0, 'dress'), (10883.0, 'sheath'), (22655.0, 'sheath'), (18264.0, 'dress'), (223.0, 'gown'), (11507.0, 'dress'), (7326.0, 'dress'), (7637.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 21347: [(22933.0, 'dress'), (21847.0, 'dress')]
#
# Top 10 recommended new items for user 21347: [(4779.0, 'dress'), (28598.0, 'blazer'), (22655.0, 'sheath'), (27119.0, 'jumpsuit'), (288.0, 'dress'), (1416.0, 'dress'), (39.0, 'gown'), (1323.0, 'gown'), (9499.0, 'dress'), (1557.0, 'shift')]
# -------------------------------------------------------------
# Random 10 rented items for user 96369: [(183.0, 'gown'), (18777.0, 'gown'), (16162.0, 'dress'), (1450.0, 'dress')]
#
# Top 10 recommended new items for user 96369: [(27357.0, 'blazer'), (1204.0, 'gown'), (172.0, 'dress'), (27119.0, 'jumpsuit'), (11507.0, 'dress'), (15920.0, 'sheath'), (16830.0, 'dress'), (13679.0, 'dress'), (11966.0, 'dress'), (218.0, 'gown')]
# -------------------------------------------------------------
# Random 10 rented items for user 408838: [(16162.0, 'dress'), (83.0, 'dress')]
#
# Top 10 recommended new items for user 408838: [(16009.0, 'maxi'), (11966.0, 'dress'), (12630.0, 'dress'), (526.0, 'dress'), (480.0, 'dress'), (11507.0, 'dress'), (17692.0, 'dress'), (23303.0, 'sheath'), (3798.0, 'dress'), (27119.0, 'jumpsuit')]
# -------------------------------------------------------------
# Random 10 rented items for user 200837: [(21159.0, 'sheath'), (13962.0, 'gown'), (17278.0, 'dress'), (16162.0, 'dress'), (243.0, 'gown')]
#
# Top 10 recommended new items for user 200837: [(27119.0, 'jumpsuit'), (11507.0, 'dress'), (23303.0, 'sheath'), (20411.0, 'dress'), (17925.0, 'sheath'), (3886.0, 'dress'), (20409.0, 'dress'), (19306.0, 'gown'), (2171.0, 'dress'), (1135.0, 'gown')]
# -------------------------------------------------------------
# Random 10 rented items for user 321447: [(14602.0, 'dress'), (14145.0, 'dress'), (29294.0, 'romper'), (27529.0, 'romper')]
#
# Top 10 recommended new items for user 321447: [(8003.0, 'dress'), (19787.0, 'dress'), (1604.0, 'dress'), (11507.0, 'dress'), (17879.0, 'dress'), (29042.0, 'jacket'), (19596.0, 'gown'), (212.0, 'gown'), (23900.0, 'romper'), (12151.0, 'gown')]
# -------------------------------------------------------------
# Random 10 rented items for user 961107: [(26855.0, 'jumpsuit'), (1367.0, 'dress'), (22654.0, 'sheath'), (14007.0, 'gown'), (1611.0, 'maxi'), (29294.0, 'romper'), (10883.0, 'sheath'), (1276.0, 'mini'), (1257.0, 'gown')]
#
# Top 10 recommended new items for user 961107: [(27119.0, 'jumpsuit'), (7684.0, 'dress'), (528.0, 'dress'), (27762.0, 'jumpsuit'), (1451.0, 'dress'), (18263.0, 'dress'), (11507.0, 'dress'), (9408.0, 'sheath'), (17974.0, 'dress'), (2560.0, 'maxi')]
# -------------------------------------------------------------
# Random 10 rented items for user 250765: [(7637.0, 'dress')]
#
# Top 10 recommended new items for user 250765: [(11507.0, 'dress'), (19787.0, 'dress'), (13679.0, 'dress'), (10883.0, 'sheath'), (11966.0, 'dress'), (17879.0, 'dress'), (12630.0, 'dress'), (65.0, 'dress'), (29042.0, 'jacket'), (544.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 777877: [(29042.0, 'jacket'), (20411.0, 'dress'), (23199.0, 'dress'), (7637.0, 'dress'), (1452.0, 'dress')]
#
# Top 10 recommended new items for user 777877: [(27119.0, 'jumpsuit'), (10883.0, 'sheath'), (8070.0, 'dress'), (19787.0, 'dress'), (12385.0, 'dress'), (11743.0, 'dress'), (27357.0, 'blazer'), (1258.0, 'gown'), (14429.0, 'sheath'), (2560.0, 'maxi')]
# -------------------------------------------------------------
# Random 10 rented items for user 901868: [(6133.0, 'dress'), (12082.0, 'dress'), (7756.0, 'dress'), (7637.0, 'dress'), (17879.0, 'dress'), (20457.0, 'dress'), (971.0, 'sheath')]
#
# Top 10 recommended new items for user 901868: [(22034.0, 'dress'), (23912.0, 'legging'), (27357.0, 'blazer'), (1451.0, 'dress'), (17787.0, 'sheath'), (1176.0, 'dress'), (21780.0, 'sheath'), (11743.0, 'dress'), (18707.0, 'sheath'), (27119.0, 'jumpsuit')]
# -------------------------------------------------------------
# Random 10 rented items for user 859301: [(24584.0, 'jumpsuit'), (1278.0, 'mini'), (22220.0, 'sheath'), (7637.0, 'dress'), (28975.0, 'romper'), (10884.0, 'sheath'), (936.0, 'dress')]
#
# Top 10 recommended new items for user 859301: [(11507.0, 'dress'), (10883.0, 'sheath'), (11966.0, 'dress'), (65.0, 'dress'), (8070.0, 'dress'), (27357.0, 'blazer'), (9605.0, 'dress'), (172.0, 'dress'), (9329.0, 'dress'), (544.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 386336: [(7637.0, 'dress'), (216.0, 'gown')]
#
# Top 10 recommended new items for user 386336: [(16830.0, 'dress'), (537.0, 'sheath'), (28598.0, 'blazer'), (4783.0, 'dress'), (24584.0, 'jumpsuit'), (22127.0, 'gown'), (11507.0, 'dress'), (22934.0, 'dress'), (23199.0, 'dress'), (27762.0, 'jumpsuit')]
# -------------------------------------------------------------
# Random 10 rented items for user 539191: [(7637.0, 'dress'), (10303.0, 'dress')]
#
# Top 10 recommended new items for user 539191: [(11507.0, 'dress'), (2171.0, 'dress'), (27119.0, 'jumpsuit'), (10883.0, 'sheath'), (4816.0, 'sheath'), (8094.0, 'dress'), (12630.0, 'dress'), (2276.0, 'dress'), (528.0, 'dress'), (27357.0, 'blazer')]
# -------------------------------------------------------------
# Random 10 rented items for user 520431: [(7637.0, 'dress')]
#
# Top 10 recommended new items for user 520431: [(11507.0, 'dress'), (27357.0, 'blazer'), (9605.0, 'dress'), (12630.0, 'dress'), (23304.0, 'sheath'), (19477.0, 'dress'), (13679.0, 'dress'), (18954.0, 'dress'), (65.0, 'dress'), (10373.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 855337: [(1690.0, 'dress'), (20713.0, 'sheath'), (23057.0, 'dress'), (8852.0, 'dress'), (1614.0, 'maxi'), (5781.0, 'dress'), (14304.0, 'dress'), (16009.0, 'maxi'), (527.0, 'dress'), (16715.0, 'dress')]
#
# Top 10 recommended new items for user 855337: [(11296.0, 'dress'), (11966.0, 'dress'), (11507.0, 'dress'), (12154.0, 'gown'), (12630.0, 'dress'), (65.0, 'dress'), (29558.0, 'jumpsuit'), (335.0, 'gown'), (9295.0, 'gown'), (22034.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 134521: [(1614.0, 'maxi'), (1375.0, 'dress')]
#
# Top 10 recommended new items for user 134521: [(528.0, 'dress'), (22034.0, 'dress'), (8536.0, 'dress'), (16715.0, 'dress'), (27357.0, 'blazer'), (17786.0, 'sheath'), (971.0, 'sheath'), (11507.0, 'dress'), (7637.0, 'dress'), (17444.0, 'gown')]
# -------------------------------------------------------------
# Random 10 rented items for user 771439: [(17879.0, 'dress'), (16009.0, 'maxi'), (2533.0, 'dress'), (1614.0, 'maxi'), (24584.0, 'jumpsuit'), (20168.0, 'gown')]
#
# Top 10 recommended new items for user 771439: [(39.0, 'gown'), (65.0, 'dress'), (19787.0, 'dress'), (243.0, 'gown'), (4816.0, 'sheath'), (12151.0, 'gown'), (29558.0, 'jumpsuit'), (11507.0, 'dress'), (23912.0, 'legging'), (528.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 76139: [(10375.0, 'dress'), (527.0, 'dress'), (1739.0, 'dress'), (14304.0, 'dress'), (18951.0, 'dress')]
#
# Top 10 recommended new items for user 76139: [(12630.0, 'dress'), (13679.0, 'dress'), (1604.0, 'dress'), (14.0, 'gown'), (27119.0, 'jumpsuit'), (23303.0, 'sheath'), (8070.0, 'dress'), (27762.0, 'jumpsuit'), (11507.0, 'dress'), (11966.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 601243: [(1690.0, 'dress'), (9738.0, 'dress')]
#
# Top 10 recommended new items for user 601243: [(16830.0, 'dress'), (11966.0, 'dress'), (17925.0, 'sheath'), (29558.0, 'jumpsuit'), (1416.0, 'dress'), (23058.0, 'dress'), (556.0, 'gown'), (23303.0, 'sheath'), (11507.0, 'dress'), (1135.0, 'gown')]
# -------------------------------------------------------------
# Random 10 rented items for user 500378: [(17669.0, 'dress'), (243.0, 'gown'), (300.0, 'gown'), (1690.0, 'dress'), (10884.0, 'sheath'), (662.0, 'dress'), (7089.0, 'gown')]
#
# Top 10 recommended new items for user 500378: [(11507.0, 'dress'), (27119.0, 'jumpsuit'), (1005.0, 'mini'), (14158.0, 'shift'), (10883.0, 'sheath'), (528.0, 'dress'), (24585.0, 'jumpsuit'), (83.0, 'dress'), (19315.0, 'sheath'), (4779.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 820028: [(876.0, 'dress'), (526.0, 'dress'), (1406.0, 'dress'), (1690.0, 'dress'), (581.0, 'gown')]
#
# Top 10 recommended new items for user 820028: [(1082.0, 'dress'), (7155.0, 'sheath'), (16830.0, 'dress'), (39.0, 'gown'), (1375.0, 'dress'), (4602.0, 'gown'), (17925.0, 'sheath'), (16009.0, 'maxi'), (1619.0, 'maxi'), (27357.0, 'blazer')]
# -------------------------------------------------------------
# Random 10 rented items for user 411872: [(23413.0, 'shift'), (168.0, 'dress'), (16503.0, 'dress'), (1690.0, 'dress'), (1094.0, 'dress')]
#
# Top 10 recommended new items for user 411872: [(27357.0, 'blazer'), (386.0, 'gown'), (22892.0, 'sheath'), (11966.0, 'dress'), (12291.0, 'dress'), (1323.0, 'gown'), (8536.0, 'dress'), (528.0, 'dress'), (17879.0, 'dress'), (11507.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 517738: [(5781.0, 'dress')]
#
# Top 10 recommended new items for user 517738: [(19787.0, 'dress'), (11507.0, 'dress'), (27357.0, 'blazer'), (27119.0, 'jumpsuit'), (341.0, 'gown'), (8003.0, 'dress'), (212.0, 'gown'), (11966.0, 'dress'), (13679.0, 'dress'), (526.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 51748: [(5781.0, 'dress')]
#
# Top 10 recommended new items for user 51748: [(19787.0, 'dress'), (11507.0, 'dress'), (19315.0, 'sheath'), (27357.0, 'blazer'), (528.0, 'dress'), (537.0, 'sheath'), (212.0, 'gown'), (341.0, 'gown'), (27119.0, 'jumpsuit'), (526.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 540884: [(8852.0, 'dress'), (4780.0, 'dress'), (16830.0, 'dress')]
# Top 10 recommended new items for user 540884: [(16009.0, 'maxi'), (22654.0, 'sheath'), (23303.0, 'sheath'), (2560.0, 'maxi'), (2171.0, 'dress'), (528.0, 'dress'), (662.0, 'dress'), (1087.0, 'dress'), (11507.0, 'dress'), (1081.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 635670: [(12668.0, 'dress'), (9605.0, 'dress'), (83.0, 'dress'), (16715.0, 'dress'), (10884.0, 'sheath'), (19768.0, 'dress')]
#
# Top 10 recommended new items for user 635670: [(9011.0, 'dress'), (24585.0, 'jumpsuit'), (11507.0, 'dress'), (1241.0, 'dress'), (17879.0, 'dress'), (22934.0, 'dress'), (27357.0, 'blazer'), (11966.0, 'dress'), (22933.0, 'dress'), (6979.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 772324: [(23057.0, 'dress'), (8391.0, 'sheath'), (14429.0, 'sheath')]
#
# Top 10 recommended new items for user 772324: [(528.0, 'dress'), (22127.0, 'gown'), (4816.0, 'sheath'), (11507.0, 'dress'), (544.0, 'sheath'), (13488.0, 'sheath'), (490.0, 'gown'), (17789.0, 'sheath'), (1451.0, 'dress'), (24584.0, 'jumpsuit')]
# -------------------------------------------------------------
# Random 10 rented items for user 416568: [(23057.0, 'dress'), (17511.0, 'gown'), (546.0, 'sheath')]
#
# Top 10 recommended new items for user 416568: [(27119.0, 'jumpsuit'), (19787.0, 'dress'), (528.0, 'dress'), (27357.0, 'blazer'), (212.0, 'gown'), (23303.0, 'sheath'), (12151.0, 'gown'), (11507.0, 'dress'), (17879.0, 'dress'), (1388.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 107556: [(16009.0, 'maxi')]
#
# Top 10 recommended new items for user 107556: [(528.0, 'dress'), (11507.0, 'dress'), (2171.0, 'dress'), (27119.0, 'jumpsuit'), (65.0, 'dress'), (23303.0, 'sheath'), (5778.0, 'dress'), (17879.0, 'dress'), (30420.0, 'romper'), (3798.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 611557: [(16009.0, 'maxi'), (19787.0, 'dress')]
#
# Top 10 recommended new items for user 611557: [(27119.0, 'jumpsuit'), (22034.0, 'dress'), (16715.0, 'dress'), (65.0, 'dress'), (30420.0, 'romper'), (9408.0, 'sheath'), (2560.0, 'maxi'), (67.0, 'dress'), (27357.0, 'blazer'), (20195.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 295662: [(527.0, 'dress'), (17444.0, 'gown')]
#
# Top 10 recommended new items for user 295662: [(11507.0, 'dress'), (27119.0, 'jumpsuit'), (20411.0, 'dress'), (8070.0, 'dress'), (27762.0, 'jumpsuit'), (22220.0, 'sheath'), (4816.0, 'sheath'), (9499.0, 'dress'), (11966.0, 'dress'), (556.0, 'gown')]
# -------------------------------------------------------------
# Random 10 rented items for user 991099: [(1611.0, 'maxi'), (28447.0, 'jumpsuit'), (212.0, 'gown'), (527.0, 'dress'), (41.0, 'gown')]
#
# Top 10 recommended new items for user 991099: [(19593.0, 'gown'), (22892.0, 'sheath'), (1323.0, 'gown'), (820.0, 'gown'), (12291.0, 'dress'), (27357.0, 'blazer'), (11122.0, 'dress'), (15859.0, 'maxi'), (22808.0, 'dress'), (24584.0, 'jumpsuit')]
# -------------------------------------------------------------
# Random 10 rented items for user 316497: [(19742.0, 'sheath'), (23058.0, 'dress'), (527.0, 'dress'), (1390.0, 'dress')]
#
# Top 10 recommended new items for user 316497: [(11507.0, 'dress'), (19593.0, 'gown'), (22892.0, 'sheath'), (20411.0, 'dress'), (22220.0, 'sheath'), (8070.0, 'dress'), (17879.0, 'dress'), (417.0, 'gown'), (556.0, 'gown'), (11966.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 258496: [(9607.0, 'dress'), (528.0, 'dress'), (801.0, 'sheath'), (20713.0, 'sheath'), (1711.0, 'dress')]
#
# Top 10 recommended new items for user 258496: [(27357.0, 'blazer'), (10883.0, 'sheath'), (11507.0, 'dress'), (526.0, 'dress'), (13679.0, 'dress'), (1204.0, 'gown'), (11966.0, 'dress'), (1094.0, 'dress'), (15920.0, 'sheath'), (24585.0, 'jumpsuit')]
# -------------------------------------------------------------
# Random 10 rented items for user 942693: [(297.0, 'gown'), (22808.0, 'dress'), (811.0, 'gown'), (18779.0, 'gown'), (2252.0, 'dress')]
#
# Top 10 recommended new items for user 942693: [(11507.0, 'dress'), (27357.0, 'blazer'), (20712.0, 'sheath'), (29558.0, 'jumpsuit'), (4816.0, 'sheath'), (19787.0, 'dress'), (9605.0, 'dress'), (17879.0, 'dress'), (23912.0, 'legging'), (10883.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 297521: [(18779.0, 'gown'), (1177.0, 'dress')]
#
# Top 10 recommended new items for user 297521: [(10883.0, 'sheath'), (8070.0, 'dress'), (11507.0, 'dress'), (7637.0, 'dress'), (23304.0, 'sheath'), (11966.0, 'dress'), (21951.0, 'shift'), (27357.0, 'blazer'), (1375.0, 'dress'), (8001.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 140422: [(20901.0, 'dress')]
#
# Top 10 recommended new items for user 140422: [(12385.0, 'dress'), (11599.0, 'frock'), (11966.0, 'dress'), (7637.0, 'dress'), (7155.0, 'sheath'), (17444.0, 'gown'), (886.0, 'dress'), (14158.0, 'shift'), (27357.0, 'blazer'), (1176.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 106267: [(20901.0, 'dress'), (15020.0, 'sheath')]
#
# Top 10 recommended new items for user 106267: [(7637.0, 'dress'), (8159.0, 'dress'), (11966.0, 'dress'), (27357.0, 'blazer'), (20713.0, 'sheath'), (1375.0, 'dress'), (1614.0, 'maxi'), (39.0, 'gown'), (1451.0, 'dress'), (11507.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 904958: [(9605.0, 'dress'), (1417.0, 'dress'), (20901.0, 'dress'), (14429.0, 'sheath')]
#
# Top 10 recommended new items for user 904958: [(10883.0, 'sheath'), (27357.0, 'blazer'), (7637.0, 'dress'), (986.0, 'gown'), (10882.0, 'sheath'), (7326.0, 'dress'), (218.0, 'gown'), (11507.0, 'dress'), (4816.0, 'sheath'), (11966.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 975196: [(20901.0, 'dress'), (3798.0, 'dress')]
#
# Top 10 recommended new items for user 975196: [(11966.0, 'dress'), (7326.0, 'dress'), (10883.0, 'sheath'), (27357.0, 'blazer'), (7637.0, 'dress'), (18264.0, 'dress'), (11507.0, 'dress'), (335.0, 'gown'), (27119.0, 'jumpsuit'), (1711.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 26892: [(20901.0, 'dress')]
#
# Top 10 recommended new items for user 26892: [(27357.0, 'blazer'), (11966.0, 'dress'), (7155.0, 'sheath'), (16009.0, 'maxi'), (17692.0, 'dress'), (2540.0, 'dress'), (1020.0, 'gown'), (1323.0, 'gown'), (1416.0, 'dress'), (14158.0, 'shift')]
# -------------------------------------------------------------
# Random 10 rented items for user 112320: [(20901.0, 'dress'), (1451.0, 'dress')]
#
# Top 10 recommended new items for user 112320: [(27357.0, 'blazer'), (1614.0, 'maxi'), (19787.0, 'dress'), (11507.0, 'dress'), (526.0, 'dress'), (4816.0, 'sheath'), (1375.0, 'dress'), (7756.0, 'dress'), (7637.0, 'dress'), (243.0, 'gown')]
# -------------------------------------------------------------
# Random 10 rented items for user 276572: [(20901.0, 'dress'), (8069.0, 'dress')]
#
# Top 10 recommended new items for user 276572: [(986.0, 'gown'), (27357.0, 'blazer'), (10882.0, 'sheath'), (11966.0, 'dress'), (14010.0, 'gown'), (9738.0, 'dress'), (18709.0, 'sheath'), (3798.0, 'dress'), (65.0, 'dress'), (27119.0, 'jumpsuit')]
# -------------------------------------------------------------
# Random 10 rented items for user 827596: [(20901.0, 'dress'), (10303.0, 'dress')]
#
# Top 10 recommended new items for user 827596: [(27357.0, 'blazer'), (986.0, 'gown'), (27119.0, 'jumpsuit'), (10883.0, 'sheath'), (11966.0, 'dress'), (65.0, 'dress'), (7637.0, 'dress'), (39.0, 'gown'), (14429.0, 'sheath'), (218.0, 'gown')]
# -------------------------------------------------------------
# Random 10 rented items for user 995412: [(22220.0, 'sheath'), (72.0, 'dress'), (8069.0, 'dress'), (20901.0, 'dress'), (23413.0, 'shift')]
#
# Top 10 recommended new items for user 995412: [(11966.0, 'dress'), (20408.0, 'dress'), (27357.0, 'blazer'), (335.0, 'gown'), (17511.0, 'gown'), (17692.0, 'dress'), (17426.0, 'sheath'), (67.0, 'dress'), (386.0, 'gown'), (537.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 439590: [(12385.0, 'dress'), (72.0, 'dress'), (2558.0, 'maxi'), (20901.0, 'dress'), (28447.0, 'jumpsuit')]
#
# ...
# -------------------------------------------------------------
# Random 10 rented items for user 131947: [(28598.0, 'blazer')]
#
# Top 10 recommended new items for user 131947: [(11507.0, 'dress'), (27119.0, 'jumpsuit'), (10883.0, 'sheath'), (22655.0, 'sheath'), (2171.0, 'dress'), (39.0, 'gown'), (4779.0, 'dress'), (528.0, 'dress'), (14158.0, 'shift'), (9609.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 970672: [(28598.0, 'blazer')]
#
# Top 10 recommended new items for user 970672: [(11507.0, 'dress'), (879.0, 'dress'), (2171.0, 'dress'), (4816.0, 'sheath'), (9946.0, 'dress'), (39.0, 'gown'), (1087.0, 'dress'), (27119.0, 'jumpsuit'), (8094.0, 'dress'), (2560.0, 'maxi')]
# -------------------------------------------------------------
# Random 10 rented items for user 448164: [(28598.0, 'blazer')]
#
# Top 10 recommended new items for user 448164: [(11507.0, 'dress'), (65.0, 'dress'), (39.0, 'gown'), (27357.0, 'blazer'), (10373.0, 'dress'), (2171.0, 'dress'), (27119.0, 'jumpsuit'), (23912.0, 'legging'), (7637.0, 'dress'), (4816.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 175980: [(6980.0, 'dress')]
#
# Top 10 recommended new items for user 175980: [(11966.0, 'dress'), (11507.0, 'dress'), (10883.0, 'sheath'), (13679.0, 'dress'), (544.0, 'sheath'), (27357.0, 'blazer'), (218.0, 'gown'), (7637.0, 'dress'), (331.0, 'gown'), (172.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 730602: [(6980.0, 'dress')]
#
# Top 10 recommended new items for user 730602: [(4816.0, 'sheath'), (11966.0, 'dress'), (14597.0, 'dress'), (22127.0, 'gown'), (335.0, 'gown'), (528.0, 'dress'), (750.0, 'dress'), (544.0, 'sheath'), (4783.0, 'dress'), (11507.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 348121: [(74.0, 'dress')]
#
# Top 10 recommended new items for user 348121: [(19787.0, 'dress'), (243.0, 'gown'), (528.0, 'dress'), (39.0, 'gown'), (18707.0, 'sheath'), (212.0, 'gown'), (20759.0, 'gown'), (1619.0, 'maxi'), (622.0, 'gown'), (11966.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 772923: [(11450.0, 'dress')]
#
# Top 10 recommended new items for user 772923: [(11507.0, 'dress'), (27119.0, 'jumpsuit'), (11966.0, 'dress'), (29558.0, 'jumpsuit'), (8094.0, 'dress'), (11122.0, 'dress'), (19315.0, 'sheath'), (27357.0, 'blazer'), (528.0, 'dress'), (8154.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 24677: [(1453.0, 'dress'), (1372.0, 'dress')]
#
# Top 10 recommended new items for user 24677: [(27357.0, 'blazer'), (27119.0, 'jumpsuit'), (7637.0, 'dress'), (13679.0, 'dress'), (11507.0, 'dress'), (11966.0, 'dress'), (10883.0, 'sheath'), (19787.0, 'dress'), (243.0, 'gown'), (17925.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 167512: [(1534.0, 'dress')]
#
# Top 10 recommended new items for user 167512: [(11507.0, 'dress'), (528.0, 'dress'), (8536.0, 'dress'), (27357.0, 'blazer'), (10373.0, 'dress'), (11966.0, 'dress'), (23304.0, 'sheath'), (2273.0, 'dress'), (11122.0, 'dress'), (16715.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 545454: [(6731.0, 'dress')]
#
# Top 10 recommended new items for user 545454: [(17879.0, 'dress'), (20712.0, 'sheath'), (11507.0, 'dress'), (65.0, 'dress'), (23912.0, 'legging'), (20713.0, 'sheath'), (4816.0, 'sheath'), (27119.0, 'jumpsuit'), (17692.0, 'dress'), (261.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 182971: [(446.0, 'dress')]
#
# Top 10 recommended new items for user 182971: [(16009.0, 'maxi'), (11507.0, 'dress'), (27762.0, 'jumpsuit'), (17786.0, 'sheath'), (22933.0, 'dress'), (22220.0, 'sheath'), (168.0, 'dress'), (13679.0, 'dress'), (4816.0, 'sheath'), (2171.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 452119: [(443.0, 'dress'), (508.0, 'dress')]
#
# Top 10 recommended new items for user 452119: [(16009.0, 'maxi'), (12630.0, 'dress'), (9011.0, 'dress'), (27762.0, 'jumpsuit'), (10373.0, 'dress'), (13679.0, 'dress'), (11966.0, 'dress'), (27119.0, 'jumpsuit'), (8002.0, 'dress'), (16006.0, 'maxi')]
# -------------------------------------------------------------
# Random 10 rented items for user 113893: [(20189.0, 'shift')]
#
# Top 10 recommended new items for user 113893: [(11507.0, 'dress'), (13679.0, 'dress'), (11966.0, 'dress'), (1204.0, 'gown'), (65.0, 'dress'), (14.0, 'gown'), (27357.0, 'blazer'), (1005.0, 'mini'), (243.0, 'gown'), (526.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 53764: [(4602.0, 'gown')]
#
# Top 10 recommended new items for user 53764: [(27119.0, 'jumpsuit'), (28598.0, 'blazer'), (879.0, 'dress'), (22220.0, 'sheath'), (14429.0, 'sheath'), (27762.0, 'jumpsuit'), (9499.0, 'dress'), (2171.0, 'dress'), (9408.0, 'sheath'), (11507.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 751304: [(9329.0, 'dress'), (275.0, 'dress'), (742.0, 'gown')]
#
# Top 10 recommended new items for user 751304: [(27357.0, 'blazer'), (14429.0, 'sheath'), (16503.0, 'dress'), (218.0, 'gown'), (8536.0, 'dress'), (16715.0, 'dress'), (7637.0, 'dress'), (808.0, 'gown'), (1614.0, 'maxi'), (12385.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 752510: [(1374.0, 'dress'), (779.0, 'gown'), (12285.0, 'dress')]
#
# Top 10 recommended new items for user 752510: [(528.0, 'dress'), (1020.0, 'gown'), (13679.0, 'dress'), (23303.0, 'sheath'), (212.0, 'gown'), (11966.0, 'dress'), (22892.0, 'sheath'), (1258.0, 'gown'), (4783.0, 'dress'), (19316.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 733593: [(16504.0, 'dress')]
#
# Top 10 recommended new items for user 733593: [(27119.0, 'jumpsuit'), (22655.0, 'sheath'), (27357.0, 'blazer'), (9605.0, 'dress'), (18950.0, 'dress'), (17879.0, 'dress'), (12630.0, 'dress'), (11966.0, 'dress'), (10373.0, 'dress'), (23412.0, 'shift')]
# -------------------------------------------------------------
# Random 10 rented items for user 735087: [(16504.0, 'dress')]
# Top 10 recommended new items for user 735087: [(27119.0, 'jumpsuit'), (11966.0, 'dress'), (27357.0, 'blazer'), (710.0, 'dress'), (12630.0, 'dress'), (23912.0, 'legging'), (3798.0, 'dress'), (18263.0, 'dress'), (22933.0, 'dress'), (2501.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 159233: [(20410.0, 'dress'), (9324.0, 'dress')]
#
# Top 10 recommended new items for user 159233: [(27119.0, 'jumpsuit'), (407.0, 'gown'), (877.0, 'dress'), (556.0, 'gown'), (300.0, 'gown'), (794.0, 'sheath'), (1388.0, 'dress'), (9499.0, 'dress'), (23303.0, 'sheath'), (19593.0, 'gown')]
# -------------------------------------------------------------
# Random 10 rented items for user 500817: [(18263.0, 'dress')]
#
# Top 10 recommended new items for user 500817: [(27119.0, 'jumpsuit'), (12630.0, 'dress'), (2171.0, 'dress'), (11507.0, 'dress'), (2253.0, 'dress'), (12925.0, 'dress'), (14302.0, 'dress'), (11966.0, 'dress'), (1020.0, 'gown'), (216.0, 'gown')]
# -------------------------------------------------------------
# Random 10 rented items for user 456267: [(752.0, 'dress')]
#
# Top 10 recommended new items for user 456267: [(22034.0, 'dress'), (27119.0, 'jumpsuit'), (11507.0, 'dress'), (27762.0, 'jumpsuit'), (17789.0, 'sheath'), (528.0, 'dress'), (22933.0, 'dress'), (100.0, 'gown'), (106.0, 'gown'), (537.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 517328: [(17278.0, 'dress')]
#
# Top 10 recommended new items for user 517328: [(19787.0, 'dress'), (27357.0, 'blazer'), (11507.0, 'dress'), (18950.0, 'dress'), (27119.0, 'jumpsuit'), (10883.0, 'sheath'), (3886.0, 'dress'), (2273.0, 'dress'), (16009.0, 'maxi'), (212.0, 'gown')]
# -------------------------------------------------------------
# Random 10 rented items for user 261528: [(4826.0, 'dress')]
#
# Top 10 recommended new items for user 261528: [(21951.0, 'shift'), (8094.0, 'dress'), (11507.0, 'dress'), (7637.0, 'dress'), (2276.0, 'dress'), (216.0, 'gown'), (1614.0, 'maxi'), (39.0, 'gown'), (17786.0, 'sheath'), (8070.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 796775: [(17786.0, 'sheath'), (294.0, 'gown'), (23412.0, 'shift')]
#
# Top 10 recommended new items for user 796775: [(22655.0, 'sheath'), (14429.0, 'sheath'), (8159.0, 'dress'), (27357.0, 'blazer'), (16828.0, 'dress'), (27119.0, 'jumpsuit'), (18264.0, 'dress'), (10883.0, 'sheath'), (2252.0, 'dress'), (9605.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 616928: [(113.0, 'gown'), (634.0, 'gown'), (761.0, 'sheath'), (975.0, 'sheath')]
#
# Top 10 recommended new items for user 616928: [(27357.0, 'blazer'), (24585.0, 'jumpsuit'), (11966.0, 'dress'), (20408.0, 'dress'), (7637.0, 'dress'), (386.0, 'gown'), (20196.0, 'dress'), (28977.0, 'romper'), (14485.0, 'dress'), (22892.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 840347: [(975.0, 'sheath'), (341.0, 'gown')]
#
# Top 10 recommended new items for user 840347: [(28977.0, 'romper'), (23303.0, 'sheath'), (10882.0, 'sheath'), (17925.0, 'sheath'), (18709.0, 'sheath'), (528.0, 'dress'), (19288.0, 'gown'), (820.0, 'gown'), (65.0, 'dress'), (20408.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 994907: [(12291.0, 'dress')]
#
# Top 10 recommended new items for user 994907: [(1604.0, 'dress'), (526.0, 'dress'), (23900.0, 'romper'), (27357.0, 'blazer'), (7756.0, 'dress'), (22220.0, 'sheath'), (1375.0, 'dress'), (29042.0, 'jacket'), (4816.0, 'sheath'), (17786.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 106273: [(1179.0, 'dress')]
#
# Top 10 recommended new items for user 106273: [(17444.0, 'gown'), (14429.0, 'sheath'), (1082.0, 'dress'), (769.0, 'dress'), (17975.0, 'dress'), (556.0, 'gown'), (7926.0, 'gown'), (16830.0, 'dress'), (1614.0, 'maxi'), (11966.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 727936: [(23305.0, 'sheath')]
#
# Top 10 recommended new items for user 727936: [(28598.0, 'blazer'), (11507.0, 'dress'), (27357.0, 'blazer'), (2171.0, 'dress'), (5784.0, 'dress'), (22933.0, 'dress'), (9327.0, 'dress'), (1204.0, 'gown'), (15920.0, 'sheath'), (22220.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 401021: [(389.0, 'gown')]
#
# Top 10 recommended new items for user 401021: [(11507.0, 'dress'), (13679.0, 'dress'), (22934.0, 'dress'), (23304.0, 'sheath'), (22892.0, 'sheath'), (17879.0, 'dress'), (14164.0, 'shift'), (11122.0, 'dress'), (1604.0, 'dress'), (23303.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 335672: [(1603.0, 'dress')]
#
# Top 10 recommended new items for user 335672: [(1416.0, 'dress'), (17670.0, 'dress'), (8852.0, 'dress'), (556.0, 'gown'), (243.0, 'gown'), (8070.0, 'dress'), (29558.0, 'jumpsuit'), (27119.0, 'jumpsuit'), (1240.0, 'dress'), (18707.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 930348: [(361.0, 'gown'), (19457.0, 'sheath')]
#
# Top 10 recommended new items for user 930348: [(19787.0, 'dress'), (526.0, 'dress'), (11507.0, 'dress'), (29042.0, 'jacket'), (27357.0, 'blazer'), (2276.0, 'dress'), (490.0, 'gown'), (23900.0, 'romper'), (16009.0, 'maxi'), (1375.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 910934: [(47.0, 'gown')]
#
# Top 10 recommended new items for user 910934: [(11507.0, 'dress'), (243.0, 'gown'), (11966.0, 'dress'), (1005.0, 'mini'), (65.0, 'dress'), (13679.0, 'dress'), (16009.0, 'maxi'), (7756.0, 'dress'), (14.0, 'gown'), (4816.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 474493: [(490.0, 'gown')]
#
# Top 10 recommended new items for user 474493: [(9605.0, 'dress'), (9609.0, 'dress'), (86.0, 'dress'), (18954.0, 'dress'), (11741.0, 'dress'), (23412.0, 'shift'), (28598.0, 'blazer'), (12630.0, 'dress'), (10373.0, 'dress'), (5976.0, 'print')]
# -------------------------------------------------------------
# Random 10 rented items for user 688256: [(1020.0, 'gown')]
#
# Top 10 recommended new items for user 688256: [(27762.0, 'jumpsuit'), (11507.0, 'dress'), (9946.0, 'dress'), (20407.0, 'dress'), (22933.0, 'dress'), (528.0, 'dress'), (879.0, 'dress'), (1323.0, 'gown'), (22808.0, 'dress'), (4816.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 714474: [(15920.0, 'sheath'), (17974.0, 'dress'), (17141.0, 'sheath')]
#
# Top 10 recommended new items for user 714474: [(27357.0, 'blazer'), (16009.0, 'maxi'), (1323.0, 'gown'), (13679.0, 'dress'), (12385.0, 'dress'), (7637.0, 'dress'), (16715.0, 'dress'), (17786.0, 'sheath'), (7328.0, 'dress'), (8536.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 198899: [(722.0, 'gown')]
#
# Top 10 recommended new items for user 198899: [(11507.0, 'dress'), (27762.0, 'jumpsuit'), (2276.0, 'dress'), (549.0, 'sheath'), (556.0, 'gown'), (884.0, 'dress'), (16830.0, 'dress'), (7637.0, 'dress'), (11966.0, 'dress'), (9499.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 266462: [(8538.0, 'dress')]
#
# Top 10 recommended new items for user 266462: [(27119.0, 'jumpsuit'), (7326.0, 'dress'), (12925.0, 'dress'), (537.0, 'sheath'), (11966.0, 'dress'), (10883.0, 'sheath'), (249.0, 'gown'), (18264.0, 'dress'), (223.0, 'gown'), (14597.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 293159: [(14025.0, 'dress')]
#
# Top 10 recommended new items for user 293159: [(16830.0, 'dress'), (288.0, 'dress'), (1416.0, 'dress'), (537.0, 'sheath'), (27357.0, 'blazer'), (21013.0, 'sheath'), (12629.0, 'dress'), (22892.0, 'sheath'), (19593.0, 'gown'), (4779.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 601986: [(18073.0, 'gown')]
#
# Top 10 recommended new items for user 601986: [(22655.0, 'sheath'), (10883.0, 'sheath'), (7637.0, 'dress'), (18264.0, 'dress'), (27119.0, 'jumpsuit'), (21951.0, 'shift'), (8159.0, 'dress'), (300.0, 'gown'), (11507.0, 'dress'), (1178.0, 'dress')]
# -------------------------------------------------------------
# Random 10 rented items for user 230384: [(20718.0, 'dress')]
#
# Top 10 recommended new items for user 230384: [(27119.0, 'jumpsuit'), (27357.0, 'blazer'), (30420.0, 'romper'), (168.0, 'dress'), (29294.0, 'romper'), (1417.0, 'dress'), (11507.0, 'dress'), (2171.0, 'dress'), (19769.0, 'dress'), (19739.0, 'sheath')]
# -------------------------------------------------------------
# Random 10 rented items for user 192415: [(737.0, 'gown'), (15108.0, 'sheath')]
# Top 10 recommended new items for user 192415: [(16830.0, 'dress'), (23303.0, 'sheath'), (11507.0, 'dress'), (544.0, 'sheath'), (17879.0, 'dress'), (27119.0, 'jumpsuit'), (29042.0, 'jacket'), (1135.0, 'gown'), (528.0, 'dress'), (24584.0, 'jumpsuit')]
# -------------------------------------------------------------
# Number of recommended item sets (SVDpp): 755

# %%
## compare results for SVDpp

df_exist = pd.DataFrame.from_dict(SVDpp_exist_dict,orient='index',\
                                  columns=['rent1','rent2','rent3',\
                                           'rent4','rent5','rent6',\
                                           'rent7','rent8','rent9',\
                                           'rent10']).reset_index()

df_rec = pd.DataFrame.from_dict(SVDpp_recc_dict, orient='index',\
                                columns=['rec1','rec2','rec3','rec4',\
                                         'rec5','rec6','rec7','rec8',\
                                         'rec9','rec10']).reset_index()

df_compare = pd.concat([df_exist, df_rec], axis=1).\
rename(columns={'index':'item ID'})

df_compare
# Out:
#      item ID                rent1              rent2              rent3  \
# 0     610914       (751.0, dress)               None               None
# 1      53519       (751.0, dress)    (8003.0, dress)               None
# 2     470639        (414.0, gown)     (528.0, dress)   (22588.0, dress)
# 3     276186       (804.0, dress)               None               None
# 4     748397     (17879.0, dress)    (800.0, sheath)    (5093.0, dress)
# 5     856829      (9499.0, dress)     (1276.0, mini)     (804.0, dress)
# 6     990544       (804.0, dress)               None               None
# 7     214108      (8157.0, dress)               None               None
# 8     503301       (524.0, dress)    (1387.0, dress)    (8157.0, dress)
# 9     574571     (16499.0, dress)     (1005.0, mini)    (8157.0, dress)
# 10    407375       (1304.0, gown)               None               None
# 11     78488        (584.0, gown)   (4816.0, sheath)     (1304.0, gown)
# 12    871986    (24183.0, romper)               None               None
# 13    290985       (1204.0, gown)      (65.0, dress)    (9604.0, dress)
# 14     26196      (3886.0, dress)      (212.0, gown)    (2159.0, dress)
# 15    166307     (18254.0, dress)      (72.0, dress)   (16609.0, dress)
# 16    234006        (418.0, gown)   (14306.0, dress)     (170.0, dress)
# 17    408945    (13488.0, sheath)      (137.0, gown)   (12669.0, dress)
# 18    480020       (170.0, dress)      (85.0, dress)    (7637.0, dress)
# 19    916978       (170.0, dress)    (4783.0, dress)      (567.0, gown)
# 20    971553       (170.0, dress)    (5783.0, dress)     (523.0, shift)
# 21    526586       (170.0, dress)               None               None
# 22    648369       (170.0, dress)   (12289.0, dress)               None
# 23    339506       (170.0, dress)     (710.0, dress)     (2560.0, maxi)
# 24    571227       (170.0, dress)               None               None
# 25    968500  (29560.0, jumpsuit)     (169.0, dress)               None
# 26    806600     (14306.0, dress)               None               None
# 27     84770     (14306.0, dress)   (21954.0, shift)   (10377.0, dress)
# 28    269712  (29231.0, jumpsuit)  (20951.0, sheath)    (1592.0, dress)
# 29    736692     (11122.0, dress)               None               None
# ..       ...                  ...                ...                ...
# 725   113893     (20189.0, shift)               None               None
# 726    53764       (4602.0, gown)               None               None
# 727   751304      (9329.0, dress)     (275.0, dress)      (742.0, gown)
# 728   752510      (1374.0, dress)      (779.0, gown)   (12285.0, dress)
# 729   733593     (16504.0, dress)               None               None
# 730   735087     (16504.0, dress)               None               None
# 731   159233     (20410.0, dress)    (9324.0, dress)               None
# 732   500817     (18263.0, dress)               None               None
# 733   456267       (752.0, dress)               None               None
# 734   517328     (17278.0, dress)               None               None
# 735   261528      (4826.0, dress)               None               None
# 736   796775    (17786.0, sheath)      (294.0, gown)   (23412.0, shift)
# 737   616928        (113.0, gown)      (634.0, gown)    (761.0, sheath)
# 738   840347      (975.0, sheath)      (341.0, gown)               None
# 739   994907     (12291.0, dress)               None               None
# 740   106273      (1179.0, dress)               None               None
# 741   727936    (23305.0, sheath)               None               None
# 742   401021        (389.0, gown)               None               None
# 743   335672      (1603.0, dress)               None               None
# 744   930348        (361.0, gown)  (19457.0, sheath)               None
# 745   910934         (47.0, gown)               None               None
# 746   474493        (490.0, gown)               None               None
# 747   688256       (1020.0, gown)               None               None
# 748   714474    (15920.0, sheath)   (17974.0, dress)  (17141.0, sheath)
# 749   198899        (722.0, gown)               None               None
# 750   266462      (8538.0, dress)               None               None
# 751   293159     (14025.0, dress)               None               None
# 752   601986      (18073.0, gown)               None               None
# 753   230384     (20718.0, dress)               None               None
# 754   192415        (737.0, gown)  (15108.0, sheath)               None
#
#                    rent4                rent5            rent6  \
# 0                   None                 None             None
# 1                   None                 None             None
# 2         (751.0, dress)       (878.0, dress)             None
# 3                   None                 None             None
# 4         (804.0, dress)  (26856.0, jumpsuit)             None
# 5        (545.0, sheath)                 None             None
# 6                   None                 None             None
# 7                   None                 None             None
# 8        (1450.0, dress)                 None             None
# 9        (1602.0, dress)                 None             None
# 10                  None                 None             None
# 11      (20188.0, shift)                 None             None
# 12                  None                 None             None
# 13     (24183.0, romper)    (18707.0, sheath)   (269.0, dress)
# 14     (24183.0, romper)    (28976.0, romper)  (15587.0, gown)
# 15     (24183.0, romper)    (19742.0, sheath)  (539.0, sheath)
# 16   (29560.0, jumpsuit)                 None             None
# 17        (170.0, dress)       (274.0, dress)   (1264.0, gown)
# 18                  None                 None             None
# 19                  None                 None             None
# 20                  None                 None             None
# 21                  None                 None             None
# 22                  None                 None             None
# 23                  None                 None             None
# 24                  None                 None             None
# 25                  None                 None             None
# 26                  None                 None             None
# 27                  None                 None             None
# 28      (11122.0, dress)    (21781.0, sheath)             None
# 29                  None                 None             None
# ..                   ...                  ...              ...
# 725                 None                 None             None
# 726                 None                 None             None
# 727                 None                 None             None
# 728                 None                 None             None
# 729                 None                 None             None
# 730                 None                 None             None
# 731                 None                 None             None
# 732                 None                 None             None
# 733                 None                 None             None
# 734                 None                 None             None
# 735                 None                 None             None
# 736                 None                 None             None
# 737      (975.0, sheath)                 None             None
# 738                 None                 None             None
# 739                 None                 None             None
# 740                 None                 None             None
# 741                 None                 None             None
# 742                 None                 None             None
# 743                 None                 None             None
# 744                 None                 None             None
# 745                 None                 None             None
# 746                 None                 None             None
# 747                 None                 None             None
# 748                 None                 None             None
# 749                 None                 None             None
# 750                 None                 None             None
# 751                 None                 None             None
# 752                 None                 None             None
# 753                 None                 None             None
# 754                 None                 None             None
#
#                rent7 rent8 rent9 rent10  item ID                 rec1  \
# 0               None  None  None   None   610914     (22933.0, dress)
# 1               None  None  None   None    53519    (27357.0, blazer)
# 2               None  None  None   None   470639     (11507.0, dress)
# 3               None  None  None   None   276186    (28598.0, blazer)
# 4               None  None  None   None   748397     (16828.0, dress)
# 5               None  None  None   None   856829     (11966.0, dress)
# 6               None  None  None   None   990544      (16009.0, maxi)
# 7               None  None  None   None   214108      (1604.0, dress)
# 8               None  None  None   None   503301    (20712.0, sheath)
# 9               None  None  None   None   574571     (4816.0, sheath)
# 10              None  None  None   None   407375     (4816.0, sheath)
# 11              None  None  None   None    78488       (1614.0, maxi)
# 12              None  None  None   None   871986  (27119.0, jumpsuit)
# 13   (800.0, sheath)  None  None   None   290985     (19787.0, dress)
# 14   (971.0, sheath)  None  None   None    26196     (11507.0, dress)
# 15              None  None  None   None   166307     (13679.0, dress)
# 16              None  None  None   None   234006     (11507.0, dress)
# 17     (701.0, gown)  None  None   None   408945     (11507.0, dress)
# 18              None  None  None   None   480020  (27119.0, jumpsuit)
# 19              None  None  None   None   916978     (11507.0, dress)
# 20              None  None  None   None   971553     (11507.0, dress)
# 21              None  None  None   None   526586     (13679.0, dress)
# 22              None  None  None   None   648369      (7637.0, dress)
# 23              None  None  None   None   339506     (11966.0, dress)
# 24              None  None  None   None   571227      (972.0, sheath)
# 25              None  None  None   None   968500      (2501.0, dress)
# 26              None  None  None   None   806600     (11507.0, dress)
# 27              None  None  None   None    84770  (27119.0, jumpsuit)
# 28              None  None  None   None   269712     (11507.0, dress)
# 29              None  None  None   None   736692     (11507.0, dress)
# ..               ...   ...   ...    ...      ...                  ...
# 725             None  None  None   None   113893     (11507.0, dress)
# 726             None  None  None   None    53764  (27119.0, jumpsuit)
# 727             None  None  None   None   751304    (27357.0, blazer)
# 728             None  None  None   None   752510       (528.0, dress)
# 729             None  None  None   None   733593  (27119.0, jumpsuit)
# 730             None  None  None   None   735087  (27119.0, jumpsuit)
# 731             None  None  None   None   159233  (27119.0, jumpsuit)
# 732             None  None  None   None   500817  (27119.0, jumpsuit)
# 733             None  None  None   None   456267     (22034.0, dress)
# 734             None  None  None   None   517328     (19787.0, dress)
# 735             None  None  None   None   261528     (21951.0, shift)
# 736             None  None  None   None   796775    (22655.0, sheath)
# 737             None  None  None   None   616928    (27357.0, blazer)
# 738             None  None  None   None   840347    (28977.0, romper)
# 739             None  None  None   None   994907      (1604.0, dress)
# 740             None  None  None   None   106273      (17444.0, gown)
# 741             None  None  None   None   727936    (28598.0, blazer)
# 742             None  None  None   None   401021     (11507.0, dress)
# 743             None  None  None   None   335672      (1416.0, dress)
# 744             None  None  None   None   930348     (19787.0, dress)
# 745             None  None  None   None   910934     (11507.0, dress)
# 746             None  None  None   None   474493      (9605.0, dress)
# 747             None  None  None   None   688256  (27762.0, jumpsuit)
# 748             None  None  None   None   714474    (27357.0, blazer)
# 749             None  None  None   None   198899     (11507.0, dress)
# 750             None  None  None   None   266462  (27119.0, jumpsuit)
# 751             None  None  None   None   293159     (16830.0, dress)
# 752             None  None  None   None   601986    (22655.0, sheath)
# 753             None  None  None   None   230384  (27119.0, jumpsuit)
# 754             None  None  None   None   192415     (16830.0, dress)
#
#                     rec2                 rec3                 rec4  \
# 0        (16009.0, maxi)     (10373.0, dress)      (17444.0, gown)
# 1        (8536.0, dress)     (11966.0, dress)     (17879.0, dress)
# 2       (13679.0, dress)     (11966.0, dress)      (972.0, sheath)
# 3        (5784.0, dress)       (1323.0, gown)     (22808.0, dress)
# 4      (27357.0, blazer)     (19787.0, dress)      (1094.0, dress)
# 5        (8852.0, dress)  (24585.0, jumpsuit)     (11507.0, dress)
# 6       (10373.0, dress)       (1323.0, gown)     (17879.0, dress)
# 7      (23305.0, sheath)      (19593.0, gown)      (1416.0, dress)
# 8      (27357.0, blazer)     (11507.0, dress)     (4816.0, sheath)
# 9       (17879.0, dress)   (23912.0, legging)     (19787.0, dress)
# 10         (218.0, gown)      (17444.0, gown)        (67.0, dress)
# 11        (524.0, dress)     (11507.0, dress)        (417.0, gown)
# 12      (11507.0, dress)     (11966.0, dress)      (2171.0, dress)
# 13     (27357.0, blazer)    (29042.0, jacket)       (1323.0, gown)
# 14       (12154.0, gown)      (1241.0, dress)      (2171.0, dress)
# 15      (11507.0, dress)     (11966.0, dress)    (17789.0, sheath)
# 16   (27119.0, jumpsuit)    (10883.0, sheath)     (11966.0, dress)
# 17      (23058.0, dress)       (528.0, dress)     (16830.0, dress)
# 18      (18950.0, dress)      (972.0, sheath)        (212.0, gown)
# 19      (11966.0, dress)  (27119.0, jumpsuit)     (10373.0, dress)
# 20         (490.0, gown)      (9794.0, dress)     (22934.0, dress)
# 21     (22892.0, sheath)      (972.0, sheath)     (11507.0, dress)
# 22     (27357.0, blazer)      (8159.0, dress)     (11966.0, dress)
# 23     (27357.0, blazer)      (8031.0, dress)      (8159.0, dress)
# 24      (13679.0, dress)      (19306.0, gown)  (27762.0, jumpsuit)
# 25       (2540.0, dress)      (1604.0, dress)    (27357.0, blazer)
# 26       (12154.0, gown)     (19787.0, dress)    (10883.0, sheath)
# 27      (19787.0, dress)     (20411.0, dress)        (137.0, gown)
# 28   (27119.0, jumpsuit)     (11966.0, dress)      (7637.0, dress)
# 29       (12154.0, gown)    (10883.0, sheath)  (24585.0, jumpsuit)
# ..                   ...                  ...                  ...
# 725     (13679.0, dress)     (11966.0, dress)       (1204.0, gown)
# 726    (28598.0, blazer)       (879.0, dress)    (22220.0, sheath)
# 727    (14429.0, sheath)     (16503.0, dress)        (218.0, gown)
# 728       (1020.0, gown)     (13679.0, dress)    (23303.0, sheath)
# 729    (22655.0, sheath)    (27357.0, blazer)      (9605.0, dress)
# 730     (11966.0, dress)    (27357.0, blazer)       (710.0, dress)
# 731        (407.0, gown)       (877.0, dress)        (556.0, gown)
# 732     (12630.0, dress)      (2171.0, dress)     (11507.0, dress)
# 733  (27119.0, jumpsuit)     (11507.0, dress)  (27762.0, jumpsuit)
# 734    (27357.0, blazer)     (11507.0, dress)     (18950.0, dress)
# 735      (8094.0, dress)     (11507.0, dress)      (7637.0, dress)
# 736    (14429.0, sheath)      (8159.0, dress)    (27357.0, blazer)
# 737  (24585.0, jumpsuit)     (11966.0, dress)     (20408.0, dress)
# 738    (23303.0, sheath)    (10882.0, sheath)    (17925.0, sheath)
# 739       (526.0, dress)    (23900.0, romper)    (27357.0, blazer)
# 740    (14429.0, sheath)      (1082.0, dress)       (769.0, dress)
# 741     (11507.0, dress)    (27357.0, blazer)      (2171.0, dress)
# 742     (13679.0, dress)     (22934.0, dress)    (23304.0, sheath)
# 743     (17670.0, dress)      (8852.0, dress)        (556.0, gown)
# 744       (526.0, dress)     (11507.0, dress)    (29042.0, jacket)
# 745        (243.0, gown)     (11966.0, dress)       (1005.0, mini)
# 746      (9609.0, dress)        (86.0, dress)     (18954.0, dress)
# 747     (11507.0, dress)      (9946.0, dress)     (20407.0, dress)
# 748      (16009.0, maxi)       (1323.0, gown)     (13679.0, dress)
# 749  (27762.0, jumpsuit)      (2276.0, dress)      (549.0, sheath)
# 750      (7326.0, dress)     (12925.0, dress)      (537.0, sheath)
# 751       (288.0, dress)      (1416.0, dress)      (537.0, sheath)
# 752    (10883.0, sheath)      (7637.0, dress)     (18264.0, dress)
# 753    (27357.0, blazer)    (30420.0, romper)       (168.0, dress)
# 754    (23303.0, sheath)     (11507.0, dress)      (544.0, sheath)
#
#                     rec5                 rec6                 rec7  \
# 0       (4816.0, sheath)     (16715.0, dress)     (11507.0, dress)
# 1        (7637.0, dress)     (11507.0, dress)      (1176.0, dress)
# 2        (544.0, sheath)  (27762.0, jumpsuit)       (1323.0, gown)
# 3        (22127.0, gown)    (27357.0, blazer)     (11507.0, dress)
# 4       (4816.0, sheath)      (9605.0, dress)    (29042.0, jacket)
# 5        (12154.0, gown)      (1534.0, dress)        (556.0, gown)
# 6       (22808.0, dress)     (11966.0, dress)     (22588.0, dress)
# 7          (133.0, gown)       (769.0, dress)      (2540.0, dress)
# 8          (779.0, gown)         (39.0, gown)        (133.0, gown)
# 9        (1375.0, dress)    (29042.0, jacket)     (11966.0, dress)
# 10       (1179.0, dress)      (2540.0, dress)     (14597.0, dress)
# 11     (17789.0, sheath)    (10883.0, sheath)    (27357.0, blazer)
# 12     (27357.0, blazer)      (9499.0, dress)     (14302.0, dress)
# 13     (19741.0, sheath)     (22588.0, dress)      (15859.0, maxi)
# 14   (27119.0, jumpsuit)        (255.0, gown)  (29558.0, jumpsuit)
# 15       (22127.0, gown)      (544.0, sheath)      (5976.0, print)
# 16   (24585.0, jumpsuit)    (27357.0, blazer)      (8070.0, dress)
# 17       (1369.0, dress)    (23303.0, sheath)  (27119.0, jumpsuit)
# 18        (1020.0, gown)    (23303.0, sheath)      (19306.0, gown)
# 19     (19315.0, sheath)        (216.0, gown)  (24585.0, jumpsuit)
# 20      (17879.0, dress)  (27762.0, jumpsuit)      (544.0, sheath)
# 21       (19249.0, maxi)     (11966.0, dress)      (544.0, sheath)
# 22      (10502.0, dress)      (8003.0, dress)      (537.0, sheath)
# 23         (335.0, gown)  (27119.0, jumpsuit)    (22655.0, sheath)
# 24   (27119.0, jumpsuit)        (212.0, gown)    (17925.0, sheath)
# 25      (13679.0, dress)      (6980.0, dress)      (4597.0, dress)
# 26         (65.0, dress)         (39.0, gown)    (27357.0, blazer)
# 27         (65.0, dress)     (4816.0, sheath)     (11507.0, dress)
# 28      (22034.0, dress)    (10883.0, sheath)     (13679.0, dress)
# 29         (101.0, gown)     (18954.0, dress)      (9605.0, dress)
# ..                   ...                  ...                  ...
# 725        (65.0, dress)         (14.0, gown)    (27357.0, blazer)
# 726    (14429.0, sheath)  (27762.0, jumpsuit)      (9499.0, dress)
# 727      (8536.0, dress)     (16715.0, dress)      (7637.0, dress)
# 728        (212.0, gown)     (11966.0, dress)    (22892.0, sheath)
# 729     (18950.0, dress)     (17879.0, dress)     (12630.0, dress)
# 730     (12630.0, dress)   (23912.0, legging)      (3798.0, dress)
# 731        (300.0, gown)      (794.0, sheath)      (1388.0, dress)
# 732      (2253.0, dress)     (12925.0, dress)     (14302.0, dress)
# 733    (17789.0, sheath)       (528.0, dress)     (22933.0, dress)
# 734  (27119.0, jumpsuit)    (10883.0, sheath)      (3886.0, dress)
# 735      (2276.0, dress)        (216.0, gown)       (1614.0, maxi)
# 736     (16828.0, dress)  (27119.0, jumpsuit)     (18264.0, dress)
# 737      (7637.0, dress)        (386.0, gown)     (20196.0, dress)
# 738    (18709.0, sheath)       (528.0, dress)      (19288.0, gown)
# 739      (7756.0, dress)    (22220.0, sheath)      (1375.0, dress)
# 740     (17975.0, dress)        (556.0, gown)       (7926.0, gown)
# 741      (5784.0, dress)     (22933.0, dress)      (9327.0, dress)
# 742    (22892.0, sheath)     (17879.0, dress)     (14164.0, shift)
# 743        (243.0, gown)      (8070.0, dress)  (29558.0, jumpsuit)
# 744    (27357.0, blazer)      (2276.0, dress)        (490.0, gown)
# 745        (65.0, dress)     (13679.0, dress)      (16009.0, maxi)
# 746     (11741.0, dress)     (23412.0, shift)    (28598.0, blazer)
# 747     (22933.0, dress)       (528.0, dress)       (879.0, dress)
# 748     (12385.0, dress)      (7637.0, dress)     (16715.0, dress)
# 749        (556.0, gown)       (884.0, dress)     (16830.0, dress)
# 750     (11966.0, dress)    (10883.0, sheath)        (249.0, gown)
# 751    (27357.0, blazer)    (21013.0, sheath)     (12629.0, dress)
# 752  (27119.0, jumpsuit)     (21951.0, shift)      (8159.0, dress)
# 753    (29294.0, romper)      (1417.0, dress)     (11507.0, dress)
# 754     (17879.0, dress)  (27119.0, jumpsuit)    (29042.0, jacket)
#
#                     rec8                 rec9                rec10
# 0       (1551.0, sheath)     (17879.0, dress)    (28598.0, blazer)
# 1         (528.0, dress)      (1375.0, dress)        (386.0, gown)
# 2        (4783.0, dress)    (17789.0, sheath)      (9499.0, dress)
# 3        (19593.0, gown)     (10373.0, dress)      (2273.0, dress)
# 4          (212.0, gown)       (288.0, dress)       (4602.0, gown)
# 5        (2253.0, dress)      (1416.0, dress)     (10373.0, dress)
# 6         (1614.0, maxi)    (27357.0, blazer)     (11507.0, dress)
# 7         (524.0, dress)     (14158.0, shift)      (1388.0, dress)
# 8       (11966.0, dress)        (216.0, gown)    (10883.0, sheath)
# 9        (7756.0, dress)    (20712.0, sheath)    (27357.0, blazer)
# 10        (528.0, dress)  (27119.0, jumpsuit)    (14429.0, sheath)
# 11         (218.0, gown)      (7328.0, dress)      (7756.0, dress)
# 12     (28598.0, blazer)    (10883.0, sheath)       (171.0, dress)
# 13      (11966.0, dress)     (20411.0, dress)     (18950.0, dress)
# 14        (288.0, dress)  (24585.0, jumpsuit)       (1005.0, mini)
# 15       (19593.0, gown)    (23304.0, sheath)    (22892.0, sheath)
# 16   (27762.0, jumpsuit)     (19787.0, dress)        (216.0, gown)
# 17      (21408.0, dress)  (27762.0, jumpsuit)     (17879.0, dress)
# 18     (27357.0, blazer)     (12385.0, dress)     (10373.0, dress)
# 19   (29558.0, jumpsuit)     (18264.0, dress)     (19476.0, dress)
# 20      (19769.0, dress)        (989.0, gown)        (467.0, gown)
# 21         (100.0, gown)     (8391.0, sheath)    (27357.0, blazer)
# 22        (878.0, dress)     (17879.0, dress)     (23412.0, shift)
# 23       (7637.0, dress)      (975.0, sheath)      (540.0, sheath)
# 24      (11507.0, dress)    (23303.0, sheath)     (11966.0, dress)
# 25      (12630.0, dress)        (212.0, gown)     (11966.0, dress)
# 26   (27119.0, jumpsuit)     (4816.0, sheath)       (1614.0, maxi)
# 27     (22654.0, sheath)       (2560.0, maxi)    (10883.0, sheath)
# 28       (19288.0, gown)      (8003.0, dress)    (19315.0, sheath)
# 29       (1241.0, dress)    (23304.0, sheath)     (12630.0, dress)
# ..                   ...                  ...                  ...
# 725       (1005.0, mini)        (243.0, gown)       (526.0, dress)
# 726      (2171.0, dress)     (9408.0, sheath)     (11507.0, dress)
# 727        (808.0, gown)       (1614.0, maxi)     (12385.0, dress)
# 728       (1258.0, gown)      (4783.0, dress)    (19316.0, sheath)
# 729     (11966.0, dress)     (10373.0, dress)     (23412.0, shift)
# 730     (18263.0, dress)     (22933.0, dress)      (2501.0, dress)
# 731      (9499.0, dress)    (23303.0, sheath)      (19593.0, gown)
# 732     (11966.0, dress)       (1020.0, gown)        (216.0, gown)
# 733        (100.0, gown)        (106.0, gown)      (537.0, sheath)
# 734      (2273.0, dress)      (16009.0, maxi)        (212.0, gown)
# 735         (39.0, gown)    (17786.0, sheath)      (8070.0, dress)
# 736    (10883.0, sheath)      (2252.0, dress)      (9605.0, dress)
# 737    (28977.0, romper)     (14485.0, dress)    (22892.0, sheath)
# 738        (820.0, gown)        (65.0, dress)     (20408.0, dress)
# 739    (29042.0, jacket)     (4816.0, sheath)    (17786.0, sheath)
# 740     (16830.0, dress)       (1614.0, maxi)     (11966.0, dress)
# 741       (1204.0, gown)    (15920.0, sheath)    (22220.0, sheath)
# 742     (11122.0, dress)      (1604.0, dress)    (23303.0, sheath)
# 743  (27119.0, jumpsuit)      (1240.0, dress)    (18707.0, sheath)
# 744    (23900.0, romper)      (16009.0, maxi)      (1375.0, dress)
# 745      (7756.0, dress)         (14.0, gown)     (4816.0, sheath)
# 746     (12630.0, dress)     (10373.0, dress)      (5976.0, print)
# 747       (1323.0, gown)     (22808.0, dress)     (4816.0, sheath)
# 748    (17786.0, sheath)      (7328.0, dress)      (8536.0, dress)
# 749      (7637.0, dress)     (11966.0, dress)      (9499.0, dress)
# 750     (18264.0, dress)        (223.0, gown)     (14597.0, dress)
# 751    (22892.0, sheath)      (19593.0, gown)      (4779.0, dress)
# 752        (300.0, gown)     (11507.0, dress)      (1178.0, dress)
# 753      (2171.0, dress)     (19769.0, dress)    (19739.0, sheath)
# 754       (1135.0, gown)       (528.0, dress)  (24584.0, jumpsuit)
#
# [755 rows x 22 columns]

# %% [markdown]
# <div class='alert alert-danger'>
# **Other metrics to evaluate top N recommendations**:
#
# [Source 1](https://gab41.lab41.org/recommender-systems-its-not-all-about-the-accuracy-562c7dceeaff) ;
# [Source 2](https://towardsdatascience.com/evaluation-metrics-for-recommender-systems-df56c6611093) ;
# [rec metrics Python library (from source 2)](https://github.com/statisticianinstilettos/recmetrics)

# %% [markdown]
# <div class='alert alert-warning'>
# **Coverage**:
# - <font color=red>what % of user-item space can be recommended?</font>
# - **User coverage**: measures the percentage of users with at least one "good" recommendation (rating above a certain threshold). A higher value is better. (numUsers = trainset.n_users)
# - **Item coverage**: measures the percentage of recommended items (with a rating above a certain threshold). A higher value is better. (numItems = trainset.n_items)

# %%
## % of items in train set that model is able to recommend on a test set

def Coverage(predicted, length):
    """
    Computes the coverage for a list of recommendations
    Parameters:
    ----------
    predicted : a dictionary of lists (of item-rating pairs)
    
    length: integer
        The number of unique items in the whole training set
    
    Returns:
    ----------
    The coverage of the recommendations as a percent 
    rounded to 2 decimal places.
    """
    predicted_items = [iid for uid, user_ratings in predicted.items()\
                       for (iid, _) in user_ratings]
    unique_pred_items = len(set(predicted_items))
    coverage = round(unique_pred_items/(length*1.0)*100,2)/100
    return coverage

## for the top N recommendations, the train set is the whole dataset

# print('Item coverage using BaselineOnly: {:.2%}'.\
#       format(Coverage(topNPredicted_BsO,len(df))))

print('Item coverage using SVDpp: {:.2%}'.\
      format(Coverage(topNPredicted_SVDpp,len(df))))

# print('Item coverage using SVD: {:.2%}'.\
#       format(Coverage(topNPredicted_SVD,len(df))))

# print('Item coverage using KNNWithZScore: {:.2%}'.\
#       format(Coverage(topNPredicted_KNNZ,len(df))))
# Out:
# Item coverage using SVDpp: 20.49%

# %%
def UserCoverage(topNPredicted, numUsers, min_rating=4.0):
    hits = 0
    for user in topNPredicted.keys():
        hit = False
        for user_ratings in topNPredicted[user]:
            if (user_ratings[1] >= min_rating):
                hit = True
                break
        if (hit):
            hits += 1

    return hits / numUsers

# print('User coverage using BaselineOnly: {:.2%}'.\
#       format(UserCoverage(topNPredicted_BsO, len(df))))

print('User coverage using SVDpp: {:.2%}'.\
      format(UserCoverage(topNPredicted_SVDpp, len(df))))

# print('User coverage using SVD: {:.2%}'.\
#       format(UserCoverage(topNPredicted_SVD, len(df))))

# print('User coverage using KNNWithZScore: {:.2%}'.\
#       format(UserCoverage(topNPredicted_KNNZ, len(df))))
# Out:
# User coverage using SVDpp: 40.29%

# %% [markdown]
# <div class='alert alert-warning'>
# **Novelty**:
# - <font color=red>how surprising are the recommendations?</font>
# - measures how many unknown recommended items are to a user (serendipity vs popularity)
# - <font color=red>popular items: must have the best rating of 5</font>
# - higher novelty value = less popular items being recommended

# %%
df_cleaned = pd.read_csv('renttherunway_cleaned_new.csv')
print(df_cleaned.shape)

## popular items must have a rating of 5 using overall cleaned dataset

popular = df_cleaned[df_cleaned['rating']==5]['item_id_new'].value_counts()

## assign rank based on item count
ranking_pop = pd.DataFrame(popular).rename(columns={'item_id_new':\
                                                    'item_count'})
ranking_pop['rank'] = ranking_pop['item_count'].rank(method='dense',\
                                                     ascending=False)
ranking_pop.head()
# Out:
# (190004, 26)
#         item_count  rank
# 168.0          245   1.0
# 1389.0         223   2.0
# 66.0           205   3.0
# 169.0          200   4.0
# 546.0          195   5.0

# %%
def Novelty(topNPredicted):
    n = 0
    total = 0
    for user in topNPredicted.keys():
        for rating in topNPredicted[user]:
            itemID = rating[0]
            rank = ranking_pop.loc[itemID,'rank']
#             print('Item ID: {0} is ranked {1}'.format(itemID,rank))
#             if rank > 259:
#                 print('error')
            total += rank
            n += 1
    return round(total / n, 2)

# print('Novelty score using BaselineOnly: ', Novelty(topNPredicted_BsO))

print('Novelty score using SVDpp: ',\
       Novelty(topNPredicted_SVDpp))

# print('Novelty score using SVD: ', Novelty(topNPredicted_SVD))

# print('Novelty score using KNNWithZScore: ', Novelty(topNPredicted_KNNZ))
# Out:
# Novelty score using SVDpp:  85.38

# %% [markdown]
# <div class='alert alert-warning'>
# #### compare algorithms using KFold and whole data set
# - using metrics: `Precision@k` and `Recall@k` functions from Surprise library
# <img src="./screenshots/precision_recall.png" width=300 />
#
# - an item is <font color=blue>considered relevant</font> if its <font color=red>true rating $r_{ui}$</font> is <font color=red>greater than a given threshold</font>.
# - an item is <font color=blue>considered recommended</font> if its <font color=red>estimated rating $\hat r_{ui}$ is greater than the threshold</font>, and if it is <font color=red>among the k highest estimated ratings</font>.

# %%
## use precision@k and recall@k functions from Surprise library

def precision_recall_at_k(predictions, k=10, threshold=5.0):
    '''Return precision and recall at k metrics for each user.'''

    # First map the predictions to each user.
    user_est_true = defaultdict(list)
    for uid, _, true_r, est, _ in predictions:
        user_est_true[uid].append((est, true_r))

    precisions = dict()
    recalls = dict()
    for uid, user_ratings in user_est_true.items():

        # Sort user ratings by estimated value
        user_ratings.sort(key=lambda x: x[0], reverse=True)

        # Number of relevant items
        n_rel = sum((true_r >= threshold) for (_, true_r) in user_ratings)

        # Number of recommended items in top k
        n_rec_k = sum((est >= threshold) for (est, _) in user_ratings[:k])

        # Number of relevant and recommended items in top k
        n_rel_and_rec_k = sum(((true_r>=threshold) and (est>=threshold))
                              for (est, true_r) in user_ratings[:k])
        # Precision@K: Proportion of recommended items that are relevant
        precisions[uid] = n_rel_and_rec_k / n_rec_k if n_rec_k != 0 else 1

        # Recall@K: Proportion of relevant items that are recommended
        recalls[uid] = n_rel_and_rec_k / n_rel if n_rel != 0 else 1

    return precisions, recalls

# %%
# calculate average precision and recall for SVDpp

kf = KFold(n_splits=5)

algo = SVDpp(n_epochs=15,lr_all=0.005,reg_all=0.02)

pmetrics = {}
rmetrics = {}
a=1

for trainset, testset in kf.split(data1):
    algo.fit(trainset)
    predictions = algo.test(testset)
    precisions, recalls = precision_recall_at_k(predictions, k=5,\
                                                threshold=5.0)

    # Precision and recall can then be averaged over all users
    pmetrics[a] = (sum(prec for prec in precisions.values())\
                    / len(precisions))
    rmetrics[a] = (sum(rec for rec in recalls.values()) / len(recalls))
    a +=1

print('average precision for SVDpp: ',\
      float(sum(pmetrics.values()))/len(pmetrics))

print('average recall for SVDpp: ',\
      float(sum(rmetrics.values()))/len(rmetrics))
# Out:
# average precision for SVDpp:  1.0
# average recall for SVDpp:  0.30228808000928525
